# %% [markdown]
# <a href="https://colab.research.google.com/github/ryn1221/Forcast-pendakian-per-skenario/blob/main/skripsi_split_80_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Persiapan Data & library

# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade scikeras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.3.1
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.3.1
#   Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (3.5.0)
# Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 61.8 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikeras 0.13.0 requires scikit-learn>=1.4.2, but you have scikit-learn 1.3.1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.3.1 which is incompatible.
# Successfully installed scikit-learn-1.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph
import seaborn as sns # used for plot interactive graph.

import itertools

# %%
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from tensorflow import keras
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from tensorflow import keras # Import keras this way
from keras.utils import to_categorical

# %%
from keras.layers import LSTM, Conv1D, MaxPooling1D, Dropout

# %%
pred_data = pd.read_csv('/content/drive/MyDrive/TA/dataset/REGISTER PENJUALAN KARCIS THN 2022 WANA WISATA GUNUNG PANDERMAN RPH ORO - ORO OMBO BKPH PUJON.csv')
#pred_data.set_index('Date', inplace=True)

pred_data.drop("Unnamed: 8", axis=1, inplace=True)
pred_data.drop("Unnamed: 9", axis=1, inplace=True)

# %%
pred_data.head()
# Out:
#          Date SERI  NO. AWAL   NO. AKHIR  JUMLAH TERJUAL   HARGA KARCIS   \
# 0  2022-01-01    B     5017.0     5516.0            500.0        15000.0
# 1  2022-01-02    B     5517.0     5641.0            125.0        15000.0
# 2  2022-01-03    B     5642.0     5757.0            116.0        15000.0
# 3  2022-01-04    B     5758.0     5882.0            125.0        15000.0
# 4  2022-01-05    B     5883.0     5932.0             50.0        15000.0
#
#    JUMLAH PENDAPATAN KETERANGAN
# 0          7500000.0        NaN
# 1          1875000.0        NaN
# 2          1740000.0        NaN
# 3          1875000.0        NaN
# 4           750000.0        NaN

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               730 non-null    object
#  1   SERI               560 non-null    object
#  2   NO. AWAL           560 non-null    float64
#  3   NO. AKHIR          560 non-null    float64
#  4   JUMLAH TERJUAL     560 non-null    float64
#  5   HARGA KARCIS       560 non-null    float64
#  6   JUMLAH PENDAPATAN  560 non-null    float64
#  7   KETERANGAN         33 non-null     object
# dtypes: float64(5), object(3)
# memory usage: 45.8+ KB

# %%
pred_data.shape
# Out:
# (730, 8)

# %%
pred_data.describe()
# Out:
#           NO. AWAL      NO. AKHIR  JUMLAH TERJUAL   HARGA KARCIS   \
# count    560.000000    560.000000       560.000000          560.0
# mean    4592.346429   4700.237500       108.891071        15000.0
# std     3184.044205   3198.082791       133.205548            0.0
# min        1.000000      4.000000         2.000000        15000.0
# 25%     1707.000000   1768.500000        23.750000        15000.0
# 50%     4058.500000   4206.500000        60.000000        15000.0
# 75%     7335.000000   7429.500000       140.000000        15000.0
# max    10600.000000  10738.000000      1154.000000        15000.0
#
#        JUMLAH PENDAPATAN
# count       5.600000e+02
# mean        1.633366e+06
# std         1.998083e+06
# min         3.000000e+04
# 25%         3.562500e+05
# 50%         9.000000e+05
# 75%         2.100000e+06
# max         1.731000e+07

# %% [markdown]
# #Prep Data

# %%
pred_data.columns=pred_data.columns.str.replace(" ","").str.lower()
pred_data.columns=pred_data.columns.str.replace(".","_").str.lower()

# %%
pred_data=pred_data.drop(columns=['seri', 'no_awal', 'no_akhir','hargakarcis','keterangan'])

# %%
print("Shape of the dataset: ", pred_data.shape)
print("Length of the dataset: ", len(pred_data))
print("Jumlah tiket paling banyak terjual dalam satu hari : ", pred_data["jumlahterjual"].max())
print("Jumlah tiket paling sedikt terjual dalam satu hari : ", pred_data["jumlahterjual"].min())
# Out:
# Shape of the dataset:  (730, 3)
# Length of the dataset:  730
# Jumlah tiket paling banyak terjual dalam satu hari :  1154.0
# Jumlah tiket paling sedikt terjual dalam satu hari :  2.0

# %%
# Convert the 'date' column to datetime objects
pred_data['date'] = pd.to_datetime(pred_data['date'])

# %%
fig = plt.subplots( figsize = (25, 15))

sns.distplot( x = pred_data["jumlahterjual"], hist = True,
             bins = 10, kde = True,).set(title = "distribusi penjualan tiket");
# Out:
# <ipython-input-19-1dee3892c34c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x = pred_data["jumlahterjual"], hist = True,

# %%
sns.set(rc = {"figure.facecolor":"#ffffff"})

fig = plt.subplots( figsize = (25, 10))

sns.lineplot( x = pred_data["date"], y = pred_data["jumlahterjual"]);

# %%
sns.jointplot(x = "date", y = "jumlahterjual", data = pred_data, height = 8, ratio = 6, kind = "scatter");

# %%
fig = plt.figure(figsize = (15, 10))

plt.plot(pred_data["date"], pred_data["jumlahterjual"], color = "#0E7791")
plt.title("jumlah pengunjung berdasarkan tiket terjual periode 1 januari 2022 - 31 desember 2023")
plt.xlabel("date", fontsize = 15)
plt.ylabel("jumlah tiket terjual", fontsize = 15)
plt.show()

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,3):
    if not pred_data.iloc[:, j].notnull().all():
        droping_list_all.append(j)
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# [1, 2]

# %%
#mengisi nilai kosong dengan interpolasi liniear
for j in range(1,3):
    pred_data.iloc[:,j] = pred_data.iloc[:,j].interpolate(method='linear')

# %%
pred_data.isnull().sum()
# Out:
# date                0
# jumlahterjual       0
# jumlahpendapatan    0
# dtype: int64

# %%
pred_data
# Out:
#           date  jumlahterjual  jumlahpendapatan
# 0   2022-01-01          500.0         7500000.0
# 1   2022-01-02          125.0         1875000.0
# 2   2022-01-03          116.0         1740000.0
# 3   2022-01-04          125.0         1875000.0
# 4   2022-01-05           50.0          750000.0
# ..         ...            ...               ...
# 725 2023-12-27           16.0          240000.0
# 726 2023-12-28           14.0          210000.0
# 727 2023-12-29           26.0          390000.0
# 728 2023-12-30          250.0         3750000.0
# 729 2023-12-31          300.0         4500000.0
#
# [730 rows x 3 columns]

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    datetime64[ns]
#  1   jumlahterjual     730 non-null    float64
#  2   jumlahpendapatan  730 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 17.2 KB

# %% [markdown]
# #Pemodelan

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	dff = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(dff.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(dff.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# Convert the 'date' column to datetime objects and set it as the index
pred_data.set_index('date', inplace=True)

# resample the data
df_resample = pred_data.resample('W').mean()
df_resample.shape
# Out:
# (105, 2)

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 730 entries, 2022-01-01 to 2023-12-31
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jumlahterjual     730 non-null    float64
#  1   jumlahpendapatan  730 non-null    float64
# dtypes: float64(2)
# memory usage: 17.1 KB

# %% [markdown]
# ##Normalisasi

# %%
## * Note: I scale all features in range of [0,1].

## resample data per hour
values = df_resample.values

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop unused columns
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)   var1(t)   var2(t)
# 1   0.862118   0.862118  0.450886  0.450886
# 2   0.450886   0.450886  0.363124  0.363124
# 3   0.363124   0.363124  0.283816  0.283816
# 4   0.283816   0.283816  0.265298  0.265298
# 5   0.265298   0.265298  0.195652  0.195652

# %% [markdown]
# ##Split Data 80:20

# %%
# split train dan test sets
values = reframed.values

n_train_time = int(len(values) * 0.8)  # data train 80% of
train = values[:n_train_time, :]
test = values[n_train_time:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# reshaped the input into the 3D format as expected by LSTM [samples, timesteps, features].
# Out:
# (83, 1, 3) (83,) (21, 1, 3) (21,)

# %% [markdown]
# ##Model LSTM

# %%
# Fungsi untuk membuat model LSTM tanpa default parameter
def create_model(neurons, dropout_rate):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))  # Output layer
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# Membungkus model dengan KerasRegressor agar bisa digunakan dalam GridSearchCV
model = KerasRegressor(build_fn=create_model, verbose=0)

# Mendefinisikan parameter grid untuk pencarian GridSearch
param_grid = {
    'epochs': [200, 300, 500],  # Nilai epoch yang ingin diuji
    'batch_size': [32, 64, 128],  # Nilai batch size yang ingin diuji
    'model__neurons': [64, 128, 256],  # Jumlah neuron di LSTM layer, note 'model__' prefix
    'model__dropout_rate': [0.2, 0.3, 0.4]  # Dropout rate yang ingin diuji, note 'model__' prefix
}


# Menggunakan GridSearchCV untuk mencari parameter terbaik
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(train_X, train_y)

# Menampilkan hasil terbaik
print(f'Best score: {grid_result.best_score_}')
print(f'Best parameters: {grid_result.best_params_}')

# Dapatkan parameter terbaik
best_epochs = grid_result.best_params_['epochs']
best_batch_size = grid_result.best_params_['batch_size']
best_neurons = grid_result.best_params_['model__neurons']  # Access using 'model__neurons'
best_dropout_rate = grid_result.best_params_['model__dropout_rate']  # Access using 'model__dropout_rate'

# Membuat model dengan parameter terbaik yang ditemukan
best_model = create_model(neurons=best_neurons, dropout_rate=best_dropout_rate)

# Fit model dengan parameter terbaik
history = best_model.fit(train_X, train_y, epochs=best_epochs, batch_size=best_batch_size, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
# Out:
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Best score: 0.9993359299164387
# Best parameters: {'batch_size': 32, 'epochs': 500, 'model__dropout_rate': 0.2, 'model__neurons': 256}
# Epoch 1/500
# 3/3 - 3s - 1s/step - loss: 0.0869 - val_loss: 0.1281
# Epoch 2/500
# 3/3 - 0s - 50ms/step - loss: 0.0715 - val_loss: 0.1071
# Epoch 3/500
# 3/3 - 0s - 41ms/step - loss: 0.0576 - val_loss: 0.0885
# Epoch 4/500
# 3/3 - 0s - 43ms/step - loss: 0.0460 - val_loss: 0.0722
# Epoch 5/500
# 3/3 - 0s - 46ms/step - loss: 0.0359 - val_loss: 0.0581
# Epoch 6/500
# 3/3 - 0s - 47ms/step - loss: 0.0275 - val_loss: 0.0465
# Epoch 7/500
# 3/3 - 0s - 50ms/step - loss: 0.0217 - val_loss: 0.0373
# Epoch 8/500
# 3/3 - 0s - 43ms/step - loss: 0.0177 - val_loss: 0.0305
# Epoch 9/500
# 3/3 - 0s - 38ms/step - loss: 0.0151 - val_loss: 0.0260
# Epoch 10/500
# 3/3 - 0s - 60ms/step - loss: 0.0146 - val_loss: 0.0233
# Epoch 11/500
# 3/3 - 0s - 37ms/step - loss: 0.0141 - val_loss: 0.0220
# Epoch 12/500
# 3/3 - 0s - 39ms/step - loss: 0.0146 - val_loss: 0.0213
# Epoch 13/500
# 3/3 - 0s - 37ms/step - loss: 0.0154 - val_loss: 0.0208
# Epoch 14/500
# 3/3 - 0s - 38ms/step - loss: 0.0149 - val_loss: 0.0203
# Epoch 15/500
# 3/3 - 0s - 48ms/step - loss: 0.0141 - val_loss: 0.0199
# Epoch 16/500
# 3/3 - 0s - 44ms/step - loss: 0.0139 - val_loss: 0.0197
# Epoch 17/500
# 3/3 - 0s - 37ms/step - loss: 0.0130 - val_loss: 0.0195
# Epoch 18/500
# 3/3 - 0s - 50ms/step - loss: 0.0122 - val_loss: 0.0195
# Epoch 19/500
# 3/3 - 0s - 46ms/step - loss: 0.0118 - val_loss: 0.0194
# Epoch 20/500
# 3/3 - 0s - 118ms/step - loss: 0.0118 - val_loss: 0.0193
# Epoch 21/500
# 3/3 - 0s - 88ms/step - loss: 0.0118 - val_loss: 0.0190
# Epoch 22/500
# 3/3 - 0s - 111ms/step - loss: 0.0108 - val_loss: 0.0185
# Epoch 23/500
# 3/3 - 0s - 71ms/step - loss: 0.0106 - val_loss: 0.0178
# Epoch 24/500
# 3/3 - 0s - 94ms/step - loss: 0.0102 - val_loss: 0.0171
# Epoch 25/500
# 3/3 - 0s - 98ms/step - loss: 0.0100 - val_loss: 0.0163
# Epoch 26/500
# 3/3 - 0s - 66ms/step - loss: 0.0097 - val_loss: 0.0156
# Epoch 27/500
# 3/3 - 0s - 85ms/step - loss: 0.0096 - val_loss: 0.0149
# Epoch 28/500
# 3/3 - 0s - 108ms/step - loss: 0.0094 - val_loss: 0.0142
# Epoch 29/500
# 3/3 - 0s - 96ms/step - loss: 0.0085 - val_loss: 0.0136
# Epoch 30/500
# 3/3 - 0s - 70ms/step - loss: 0.0086 - val_loss: 0.0130
# Epoch 31/500
# 3/3 - 0s - 96ms/step - loss: 0.0079 - val_loss: 0.0124
# Epoch 32/500
# 3/3 - 0s - 98ms/step - loss: 0.0079 - val_loss: 0.0118
# Epoch 33/500
# 3/3 - 0s - 99ms/step - loss: 0.0070 - val_loss: 0.0113
# Epoch 34/500
# 3/3 - 0s - 75ms/step - loss: 0.0070 - val_loss: 0.0107
# Epoch 35/500
# 3/3 - 0s - 79ms/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 36/500
# 3/3 - 0s - 44ms/step - loss: 0.0064 - val_loss: 0.0097
# Epoch 37/500
# 3/3 - 0s - 46ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 38/500
# 3/3 - 0s - 45ms/step - loss: 0.0060 - val_loss: 0.0086
# Epoch 39/500
# 3/3 - 0s - 60ms/step - loss: 0.0052 - val_loss: 0.0081
# Epoch 40/500
# 3/3 - 0s - 100ms/step - loss: 0.0051 - val_loss: 0.0075
# Epoch 41/500
# 3/3 - 0s - 40ms/step - loss: 0.0047 - val_loss: 0.0070
# Epoch 42/500
# 3/3 - 0s - 44ms/step - loss: 0.0044 - val_loss: 0.0065
# Epoch 43/500
# 3/3 - 0s - 46ms/step - loss: 0.0044 - val_loss: 0.0060
# Epoch 44/500
# 3/3 - 0s - 38ms/step - loss: 0.0035 - val_loss: 0.0056
# Epoch 45/500
# 3/3 - 0s - 46ms/step - loss: 0.0035 - val_loss: 0.0051
# Epoch 46/500
# 3/3 - 0s - 41ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 47/500
# 3/3 - 0s - 36ms/step - loss: 0.0030 - val_loss: 0.0042
# Epoch 48/500
# 3/3 - 0s - 48ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 49/500
# 3/3 - 0s - 38ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 50/500
# 3/3 - 0s - 39ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 51/500
# 3/3 - 0s - 45ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 52/500
# 3/3 - 0s - 38ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 53/500
# 3/3 - 0s - 47ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 54/500
# 3/3 - 0s - 49ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 55/500
# 3/3 - 0s - 46ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 56/500
# 3/3 - 0s - 47ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 57/500
# 3/3 - 0s - 45ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 58/500
# 3/3 - 0s - 42ms/step - loss: 8.2899e-04 - val_loss: 9.4295e-04
# Epoch 59/500
# 3/3 - 0s - 47ms/step - loss: 9.5074e-04 - val_loss: 7.9569e-04
# Epoch 60/500
# 3/3 - 0s - 50ms/step - loss: 8.7822e-04 - val_loss: 6.5738e-04
# Epoch 61/500
# 3/3 - 0s - 49ms/step - loss: 6.7377e-04 - val_loss: 5.3891e-04
# Epoch 62/500
# 3/3 - 0s - 38ms/step - loss: 7.0534e-04 - val_loss: 4.4146e-04
# Epoch 63/500
# 3/3 - 0s - 37ms/step - loss: 5.8702e-04 - val_loss: 3.7188e-04
# Epoch 64/500
# 3/3 - 0s - 35ms/step - loss: 5.4071e-04 - val_loss: 3.0439e-04
# Epoch 65/500
# 3/3 - 0s - 47ms/step - loss: 3.7338e-04 - val_loss: 2.4643e-04
# Epoch 66/500
# 3/3 - 0s - 36ms/step - loss: 6.1953e-04 - val_loss: 2.0413e-04
# Epoch 67/500
# 3/3 - 0s - 38ms/step - loss: 3.1431e-04 - val_loss: 1.7750e-04
# Epoch 68/500
# 3/3 - 0s - 36ms/step - loss: 3.6240e-04 - val_loss: 1.5352e-04
# Epoch 69/500
# 3/3 - 0s - 59ms/step - loss: 2.7051e-04 - val_loss: 1.4120e-04
# Epoch 70/500
# 3/3 - 0s - 42ms/step - loss: 3.0561e-04 - val_loss: 1.4287e-04
# Epoch 71/500
# 3/3 - 0s - 50ms/step - loss: 2.3784e-04 - val_loss: 1.4567e-04
# Epoch 72/500
# 3/3 - 0s - 37ms/step - loss: 1.7859e-04 - val_loss: 1.3624e-04
# Epoch 73/500
# 3/3 - 0s - 46ms/step - loss: 2.0130e-04 - val_loss: 1.3469e-04
# Epoch 74/500
# 3/3 - 0s - 38ms/step - loss: 2.8177e-04 - val_loss: 1.4042e-04
# Epoch 75/500
# 3/3 - 0s - 38ms/step - loss: 2.4305e-04 - val_loss: 1.5990e-04
# Epoch 76/500
# 3/3 - 0s - 45ms/step - loss: 1.6791e-04 - val_loss: 1.7388e-04
# Epoch 77/500
# 3/3 - 0s - 55ms/step - loss: 2.4250e-04 - val_loss: 1.8252e-04
# Epoch 78/500
# 3/3 - 0s - 38ms/step - loss: 1.5258e-04 - val_loss: 1.7287e-04
# Epoch 79/500
# 3/3 - 0s - 45ms/step - loss: 1.5282e-04 - val_loss: 1.7052e-04
# Epoch 80/500
# 3/3 - 0s - 38ms/step - loss: 2.2149e-04 - val_loss: 1.8084e-04
# Epoch 81/500
# 3/3 - 0s - 59ms/step - loss: 1.9290e-04 - val_loss: 1.8035e-04
# Epoch 82/500
# 3/3 - 0s - 37ms/step - loss: 2.1564e-04 - val_loss: 1.7291e-04
# Epoch 83/500
# 3/3 - 0s - 39ms/step - loss: 2.1214e-04 - val_loss: 1.7369e-04
# Epoch 84/500
# 3/3 - 0s - 58ms/step - loss: 2.1409e-04 - val_loss: 1.7078e-04
# Epoch 85/500
# 3/3 - 0s - 38ms/step - loss: 1.6161e-04 - val_loss: 1.6993e-04
# Epoch 86/500
# 3/3 - 0s - 38ms/step - loss: 1.9038e-04 - val_loss: 1.7167e-04
# Epoch 87/500
# 3/3 - 0s - 46ms/step - loss: 1.7965e-04 - val_loss: 1.6684e-04
# Epoch 88/500
# 3/3 - 0s - 47ms/step - loss: 2.2663e-04 - val_loss: 1.7075e-04
# Epoch 89/500
# 3/3 - 0s - 45ms/step - loss: 2.5955e-04 - val_loss: 1.8111e-04
# Epoch 90/500
# 3/3 - 0s - 46ms/step - loss: 1.6631e-04 - val_loss: 1.8522e-04
# Epoch 91/500
# 3/3 - 0s - 36ms/step - loss: 2.4731e-04 - val_loss: 1.7984e-04
# Epoch 92/500
# 3/3 - 0s - 46ms/step - loss: 2.3340e-04 - val_loss: 1.6005e-04
# Epoch 93/500
# 3/3 - 0s - 39ms/step - loss: 1.4755e-04 - val_loss: 1.6137e-04
# Epoch 94/500
# 3/3 - 0s - 38ms/step - loss: 1.8814e-04 - val_loss: 1.5969e-04
# Epoch 95/500
# 3/3 - 0s - 37ms/step - loss: 2.1028e-04 - val_loss: 1.6274e-04
# Epoch 96/500
# 3/3 - 0s - 37ms/step - loss: 2.5702e-04 - val_loss: 2.0358e-04
# Epoch 97/500
# 3/3 - 0s - 38ms/step - loss: 1.6760e-04 - val_loss: 2.1722e-04
# Epoch 98/500
# 3/3 - 0s - 38ms/step - loss: 1.8974e-04 - val_loss: 1.9245e-04
# Epoch 99/500
# 3/3 - 0s - 37ms/step - loss: 2.0935e-04 - val_loss: 1.7277e-04
# Epoch 100/500
# 3/3 - 0s - 42ms/step - loss: 1.2906e-04 - val_loss: 1.5737e-04
# Epoch 101/500
# 3/3 - 0s - 42ms/step - loss: 2.7324e-04 - val_loss: 1.5941e-04
# Epoch 102/500
# 3/3 - 0s - 59ms/step - loss: 1.5447e-04 - val_loss: 1.6192e-04
# Epoch 103/500
# 3/3 - 0s - 37ms/step - loss: 1.9011e-04 - val_loss: 1.5699e-04
# Epoch 104/500
# 3/3 - 0s - 48ms/step - loss: 2.0981e-04 - val_loss: 1.5159e-04
# Epoch 105/500
# 3/3 - 0s - 37ms/step - loss: 1.8352e-04 - val_loss: 1.4703e-04
# Epoch 106/500
# 3/3 - 0s - 48ms/step - loss: 2.0560e-04 - val_loss: 1.4673e-04
# Epoch 107/500
# 3/3 - 0s - 47ms/step - loss: 2.3003e-04 - val_loss: 1.6755e-04
# Epoch 108/500
# 3/3 - 0s - 56ms/step - loss: 1.5879e-04 - val_loss: 1.9454e-04
# Epoch 109/500
# 3/3 - 0s - 66ms/step - loss: 1.3169e-04 - val_loss: 1.7944e-04
# Epoch 110/500
# 3/3 - 0s - 61ms/step - loss: 1.9141e-04 - val_loss: 1.5626e-04
# Epoch 111/500
# 3/3 - 0s - 104ms/step - loss: 1.7769e-04 - val_loss: 1.5232e-04
# Epoch 112/500
# 3/3 - 0s - 106ms/step - loss: 2.0933e-04 - val_loss: 1.5257e-04
# Epoch 113/500
# 3/3 - 0s - 90ms/step - loss: 3.6834e-04 - val_loss: 1.5045e-04
# Epoch 114/500
# 3/3 - 0s - 65ms/step - loss: 1.8641e-04 - val_loss: 1.9800e-04
# Epoch 115/500
# 3/3 - 0s - 55ms/step - loss: 1.6999e-04 - val_loss: 1.8536e-04
# Epoch 116/500
# 3/3 - 0s - 64ms/step - loss: 1.7554e-04 - val_loss: 1.5913e-04
# Epoch 117/500
# 3/3 - 0s - 99ms/step - loss: 1.7643e-04 - val_loss: 1.5384e-04
# Epoch 118/500
# 3/3 - 0s - 99ms/step - loss: 1.6405e-04 - val_loss: 1.5395e-04
# Epoch 119/500
# 3/3 - 0s - 69ms/step - loss: 1.8542e-04 - val_loss: 1.5812e-04
# Epoch 120/500
# 3/3 - 0s - 67ms/step - loss: 1.7950e-04 - val_loss: 1.7308e-04
# Epoch 121/500
# 3/3 - 0s - 70ms/step - loss: 1.7184e-04 - val_loss: 1.9760e-04
# Epoch 122/500
# 3/3 - 0s - 97ms/step - loss: 1.8206e-04 - val_loss: 1.9466e-04
# Epoch 123/500
# 3/3 - 0s - 106ms/step - loss: 2.4249e-04 - val_loss: 1.8197e-04
# Epoch 124/500
# 3/3 - 0s - 57ms/step - loss: 1.7188e-04 - val_loss: 1.7467e-04
# Epoch 125/500
# 3/3 - 0s - 99ms/step - loss: 1.8881e-04 - val_loss: 1.8953e-04
# Epoch 126/500
# 3/3 - 0s - 112ms/step - loss: 1.9947e-04 - val_loss: 1.9185e-04
# Epoch 127/500
# 3/3 - 0s - 79ms/step - loss: 1.8170e-04 - val_loss: 1.6991e-04
# Epoch 128/500
# 3/3 - 0s - 37ms/step - loss: 1.4012e-04 - val_loss: 1.6833e-04
# Epoch 129/500
# 3/3 - 0s - 51ms/step - loss: 2.2046e-04 - val_loss: 1.7116e-04
# Epoch 130/500
# 3/3 - 0s - 40ms/step - loss: 1.1604e-04 - val_loss: 1.8799e-04
# Epoch 131/500
# 3/3 - 0s - 36ms/step - loss: 1.6356e-04 - val_loss: 1.9423e-04
# Epoch 132/500
# 3/3 - 0s - 48ms/step - loss: 1.6724e-04 - val_loss: 1.8693e-04
# Epoch 133/500
# 3/3 - 0s - 38ms/step - loss: 1.2822e-04 - val_loss: 1.7656e-04
# Epoch 134/500
# 3/3 - 0s - 39ms/step - loss: 2.3739e-04 - val_loss: 1.7288e-04
# Epoch 135/500
# 3/3 - 0s - 49ms/step - loss: 1.5690e-04 - val_loss: 1.7582e-04
# Epoch 136/500
# 3/3 - 0s - 37ms/step - loss: 1.8203e-04 - val_loss: 1.8272e-04
# Epoch 137/500
# 3/3 - 0s - 51ms/step - loss: 1.7677e-04 - val_loss: 2.3212e-04
# Epoch 138/500
# 3/3 - 0s - 38ms/step - loss: 1.2627e-04 - val_loss: 2.3337e-04
# Epoch 139/500
# 3/3 - 0s - 37ms/step - loss: 1.7996e-04 - val_loss: 2.0725e-04
# Epoch 140/500
# 3/3 - 0s - 49ms/step - loss: 2.3957e-04 - val_loss: 1.7766e-04
# Epoch 141/500
# 3/3 - 0s - 45ms/step - loss: 1.6255e-04 - val_loss: 1.7291e-04
# Epoch 142/500
# 3/3 - 0s - 49ms/step - loss: 1.2274e-04 - val_loss: 1.7754e-04
# Epoch 143/500
# 3/3 - 0s - 38ms/step - loss: 1.0174e-04 - val_loss: 1.9371e-04
# Epoch 144/500
# 3/3 - 0s - 38ms/step - loss: 1.6137e-04 - val_loss: 1.9659e-04
# Epoch 145/500
# 3/3 - 0s - 49ms/step - loss: 1.2524e-04 - val_loss: 1.8739e-04
# Epoch 146/500
# 3/3 - 0s - 36ms/step - loss: 1.8986e-04 - val_loss: 1.8949e-04
# Epoch 147/500
# 3/3 - 0s - 47ms/step - loss: 2.1357e-04 - val_loss: 2.1887e-04
# Epoch 148/500
# 3/3 - 0s - 46ms/step - loss: 2.1974e-04 - val_loss: 1.7957e-04
# Epoch 149/500
# 3/3 - 0s - 37ms/step - loss: 1.5625e-04 - val_loss: 1.5979e-04
# Epoch 150/500
# 3/3 - 0s - 49ms/step - loss: 2.4007e-04 - val_loss: 1.6188e-04
# Epoch 151/500
# 3/3 - 0s - 37ms/step - loss: 1.3163e-04 - val_loss: 1.7727e-04
# Epoch 152/500
# 3/3 - 0s - 46ms/step - loss: 2.2919e-04 - val_loss: 1.8838e-04
# Epoch 153/500
# 3/3 - 0s - 41ms/step - loss: 3.1381e-04 - val_loss: 1.8201e-04
# Epoch 154/500
# 3/3 - 0s - 36ms/step - loss: 1.9286e-04 - val_loss: 1.4990e-04
# Epoch 155/500
# 3/3 - 0s - 38ms/step - loss: 1.6838e-04 - val_loss: 1.4468e-04
# Epoch 156/500
# 3/3 - 0s - 46ms/step - loss: 1.7304e-04 - val_loss: 1.4785e-04
# Epoch 157/500
# 3/3 - 0s - 39ms/step - loss: 2.0718e-04 - val_loss: 1.5322e-04
# Epoch 158/500
# 3/3 - 0s - 47ms/step - loss: 1.3591e-04 - val_loss: 1.6625e-04
# Epoch 159/500
# 3/3 - 0s - 39ms/step - loss: 2.0240e-04 - val_loss: 1.5456e-04
# Epoch 160/500
# 3/3 - 0s - 47ms/step - loss: 1.3656e-04 - val_loss: 1.4251e-04
# Epoch 161/500
# 3/3 - 0s - 45ms/step - loss: 1.9570e-04 - val_loss: 1.4162e-04
# Epoch 162/500
# 3/3 - 0s - 38ms/step - loss: 2.1191e-04 - val_loss: 1.4181e-04
# Epoch 163/500
# 3/3 - 0s - 46ms/step - loss: 1.2869e-04 - val_loss: 1.5359e-04
# Epoch 164/500
# 3/3 - 0s - 39ms/step - loss: 1.3482e-04 - val_loss: 1.6232e-04
# Epoch 165/500
# 3/3 - 0s - 40ms/step - loss: 1.4681e-04 - val_loss: 1.4165e-04
# Epoch 166/500
# 3/3 - 0s - 39ms/step - loss: 1.4763e-04 - val_loss: 1.2504e-04
# Epoch 167/500
# 3/3 - 0s - 45ms/step - loss: 1.9177e-04 - val_loss: 1.3501e-04
# Epoch 168/500
# 3/3 - 0s - 52ms/step - loss: 1.4711e-04 - val_loss: 1.4735e-04
# Epoch 169/500
# 3/3 - 0s - 39ms/step - loss: 1.6368e-04 - val_loss: 1.4825e-04
# Epoch 170/500
# 3/3 - 0s - 41ms/step - loss: 1.8698e-04 - val_loss: 1.4861e-04
# Epoch 171/500
# 3/3 - 0s - 45ms/step - loss: 1.3826e-04 - val_loss: 1.5951e-04
# Epoch 172/500
# 3/3 - 0s - 45ms/step - loss: 1.9340e-04 - val_loss: 1.6952e-04
# Epoch 173/500
# 3/3 - 0s - 45ms/step - loss: 1.9718e-04 - val_loss: 1.4438e-04
# Epoch 174/500
# 3/3 - 0s - 37ms/step - loss: 2.0092e-04 - val_loss: 1.3845e-04
# Epoch 175/500
# 3/3 - 0s - 51ms/step - loss: 1.7094e-04 - val_loss: 1.3221e-04
# Epoch 176/500
# 3/3 - 0s - 41ms/step - loss: 1.7558e-04 - val_loss: 1.2726e-04
# Epoch 177/500
# 3/3 - 0s - 44ms/step - loss: 2.1995e-04 - val_loss: 1.2209e-04
# Epoch 178/500
# 3/3 - 0s - 45ms/step - loss: 1.9355e-04 - val_loss: 1.1272e-04
# Epoch 179/500
# 3/3 - 0s - 47ms/step - loss: 1.1645e-04 - val_loss: 1.0668e-04
# Epoch 180/500
# 3/3 - 0s - 48ms/step - loss: 1.4251e-04 - val_loss: 1.1003e-04
# Epoch 181/500
# 3/3 - 0s - 45ms/step - loss: 1.3134e-04 - val_loss: 1.3185e-04
# Epoch 182/500
# 3/3 - 0s - 39ms/step - loss: 1.9612e-04 - val_loss: 1.5243e-04
# Epoch 183/500
# 3/3 - 0s - 37ms/step - loss: 1.3308e-04 - val_loss: 1.4556e-04
# Epoch 184/500
# 3/3 - 0s - 38ms/step - loss: 1.6306e-04 - val_loss: 1.1773e-04
# Epoch 185/500
# 3/3 - 0s - 47ms/step - loss: 9.8993e-05 - val_loss: 1.1551e-04
# Epoch 186/500
# 3/3 - 0s - 46ms/step - loss: 1.4325e-04 - val_loss: 1.1334e-04
# Epoch 187/500
# 3/3 - 0s - 34ms/step - loss: 1.7228e-04 - val_loss: 1.2610e-04
# Epoch 188/500
# 3/3 - 0s - 39ms/step - loss: 1.5289e-04 - val_loss: 1.6144e-04
# Epoch 189/500
# 3/3 - 0s - 45ms/step - loss: 1.2695e-04 - val_loss: 1.5363e-04
# Epoch 190/500
# 3/3 - 0s - 47ms/step - loss: 1.0914e-04 - val_loss: 1.4176e-04
# Epoch 191/500
# 3/3 - 0s - 59ms/step - loss: 1.9406e-04 - val_loss: 1.2253e-04
# Epoch 192/500
# 3/3 - 0s - 37ms/step - loss: 1.3903e-04 - val_loss: 1.2769e-04
# Epoch 193/500
# 3/3 - 0s - 37ms/step - loss: 1.9993e-04 - val_loss: 1.1986e-04
# Epoch 194/500
# 3/3 - 0s - 36ms/step - loss: 1.6462e-04 - val_loss: 1.2631e-04
# Epoch 195/500
# 3/3 - 0s - 50ms/step - loss: 1.5301e-04 - val_loss: 1.6228e-04
# Epoch 196/500
# 3/3 - 0s - 36ms/step - loss: 1.7377e-04 - val_loss: 1.5257e-04
# Epoch 197/500
# 3/3 - 0s - 48ms/step - loss: 1.3828e-04 - val_loss: 1.1394e-04
# Epoch 198/500
# 3/3 - 0s - 45ms/step - loss: 1.7749e-04 - val_loss: 1.1392e-04
# Epoch 199/500
# 3/3 - 0s - 39ms/step - loss: 2.7926e-04 - val_loss: 1.1173e-04
# Epoch 200/500
# 3/3 - 0s - 44ms/step - loss: 2.2146e-04 - val_loss: 1.4766e-04
# Epoch 201/500
# 3/3 - 0s - 38ms/step - loss: 1.4899e-04 - val_loss: 1.5696e-04
# Epoch 202/500
# 3/3 - 0s - 67ms/step - loss: 1.5844e-04 - val_loss: 1.1791e-04
# Epoch 203/500
# 3/3 - 0s - 102ms/step - loss: 1.3765e-04 - val_loss: 1.1282e-04
# Epoch 204/500
# 3/3 - 0s - 59ms/step - loss: 1.4282e-04 - val_loss: 1.2033e-04
# Epoch 205/500
# 3/3 - 0s - 90ms/step - loss: 2.4094e-04 - val_loss: 1.6804e-04
# Epoch 206/500
# 3/3 - 0s - 52ms/step - loss: 1.4562e-04 - val_loss: 1.5919e-04
# Epoch 207/500
# 3/3 - 0s - 117ms/step - loss: 1.2184e-04 - val_loss: 1.2661e-04
# Epoch 208/500
# 3/3 - 0s - 67ms/step - loss: 1.1296e-04 - val_loss: 1.0959e-04
# Epoch 209/500
# 3/3 - 0s - 99ms/step - loss: 1.1709e-04 - val_loss: 1.1108e-04
# Epoch 210/500
# 3/3 - 0s - 91ms/step - loss: 1.2943e-04 - val_loss: 1.4091e-04
# Epoch 211/500
# 3/3 - 0s - 53ms/step - loss: 1.4048e-04 - val_loss: 1.6394e-04
# Epoch 212/500
# 3/3 - 0s - 67ms/step - loss: 1.8108e-04 - val_loss: 1.3597e-04
# Epoch 213/500
# 3/3 - 0s - 103ms/step - loss: 1.4412e-04 - val_loss: 1.0783e-04
# Epoch 214/500
# 3/3 - 0s - 72ms/step - loss: 1.1979e-04 - val_loss: 1.0696e-04
# Epoch 215/500
# 3/3 - 0s - 67ms/step - loss: 2.5614e-04 - val_loss: 1.3292e-04
# Epoch 216/500
# 3/3 - 0s - 76ms/step - loss: 1.3176e-04 - val_loss: 1.5201e-04
# Epoch 217/500
# 3/3 - 0s - 66ms/step - loss: 1.0061e-04 - val_loss: 1.3927e-04
# Epoch 218/500
# 3/3 - 0s - 100ms/step - loss: 1.1381e-04 - val_loss: 1.2124e-04
# Epoch 219/500
# 3/3 - 0s - 93ms/step - loss: 9.6513e-05 - val_loss: 1.1195e-04
# Epoch 220/500
# 3/3 - 0s - 56ms/step - loss: 1.2954e-04 - val_loss: 1.0711e-04
# Epoch 221/500
# 3/3 - 0s - 37ms/step - loss: 1.9600e-04 - val_loss: 1.0746e-04
# Epoch 222/500
# 3/3 - 0s - 38ms/step - loss: 1.5872e-04 - val_loss: 1.1642e-04
# Epoch 223/500
# 3/3 - 0s - 42ms/step - loss: 1.4640e-04 - val_loss: 1.0543e-04
# Epoch 224/500
# 3/3 - 0s - 41ms/step - loss: 1.5619e-04 - val_loss: 9.4400e-05
# Epoch 225/500
# 3/3 - 0s - 41ms/step - loss: 1.5141e-04 - val_loss: 8.9911e-05
# Epoch 226/500
# 3/3 - 0s - 38ms/step - loss: 1.1641e-04 - val_loss: 8.7234e-05
# Epoch 227/500
# 3/3 - 0s - 51ms/step - loss: 1.6034e-04 - val_loss: 9.0923e-05
# Epoch 228/500
# 3/3 - 0s - 37ms/step - loss: 9.6077e-05 - val_loss: 8.6949e-05
# Epoch 229/500
# 3/3 - 0s - 47ms/step - loss: 1.4077e-04 - val_loss: 7.9754e-05
# Epoch 230/500
# 3/3 - 0s - 48ms/step - loss: 1.0546e-04 - val_loss: 7.8928e-05
# Epoch 231/500
# 3/3 - 0s - 46ms/step - loss: 1.2695e-04 - val_loss: 8.2582e-05
# Epoch 232/500
# 3/3 - 0s - 49ms/step - loss: 1.0928e-04 - val_loss: 9.3532e-05
# Epoch 233/500
# 3/3 - 0s - 37ms/step - loss: 1.4108e-04 - val_loss: 1.0605e-04
# Epoch 234/500
# 3/3 - 0s - 47ms/step - loss: 1.1202e-04 - val_loss: 9.8732e-05
# Epoch 235/500
# 3/3 - 0s - 48ms/step - loss: 1.4801e-04 - val_loss: 9.4038e-05
# Epoch 236/500
# 3/3 - 0s - 37ms/step - loss: 1.9060e-04 - val_loss: 9.8539e-05
# Epoch 237/500
# 3/3 - 0s - 47ms/step - loss: 1.7473e-04 - val_loss: 1.1532e-04
# Epoch 238/500
# 3/3 - 0s - 42ms/step - loss: 1.8644e-04 - val_loss: 1.1821e-04
# Epoch 239/500
# 3/3 - 0s - 56ms/step - loss: 9.2133e-05 - val_loss: 9.8837e-05
# Epoch 240/500
# 3/3 - 0s - 87ms/step - loss: 1.1825e-04 - val_loss: 9.5943e-05
# Epoch 241/500
# 3/3 - 0s - 47ms/step - loss: 1.3230e-04 - val_loss: 9.3833e-05
# Epoch 242/500
# 3/3 - 0s - 46ms/step - loss: 1.6290e-04 - val_loss: 9.0147e-05
# Epoch 243/500
# 3/3 - 0s - 40ms/step - loss: 1.3695e-04 - val_loss: 9.0443e-05
# Epoch 244/500
# 3/3 - 0s - 46ms/step - loss: 1.5898e-04 - val_loss: 9.2357e-05
# Epoch 245/500
# 3/3 - 0s - 41ms/step - loss: 1.2013e-04 - val_loss: 8.7616e-05
# Epoch 246/500
# 3/3 - 0s - 41ms/step - loss: 1.1291e-04 - val_loss: 9.3426e-05
# Epoch 247/500
# 3/3 - 0s - 39ms/step - loss: 1.7211e-04 - val_loss: 1.1375e-04
# Epoch 248/500
# 3/3 - 0s - 47ms/step - loss: 1.2912e-04 - val_loss: 1.0568e-04
# Epoch 249/500
# 3/3 - 0s - 65ms/step - loss: 1.1225e-04 - val_loss: 1.0500e-04
# Epoch 250/500
# 3/3 - 0s - 38ms/step - loss: 1.7576e-04 - val_loss: 1.2398e-04
# Epoch 251/500
# 3/3 - 0s - 45ms/step - loss: 2.2954e-04 - val_loss: 1.2392e-04
# Epoch 252/500
# 3/3 - 0s - 61ms/step - loss: 1.7780e-04 - val_loss: 9.8011e-05
# Epoch 253/500
# 3/3 - 0s - 38ms/step - loss: 1.6095e-04 - val_loss: 1.0751e-04
# Epoch 254/500
# 3/3 - 0s - 38ms/step - loss: 1.9706e-04 - val_loss: 9.3839e-05
# Epoch 255/500
# 3/3 - 0s - 39ms/step - loss: 2.1054e-04 - val_loss: 1.1757e-04
# Epoch 256/500
# 3/3 - 0s - 45ms/step - loss: 9.4515e-05 - val_loss: 9.3978e-05
# Epoch 257/500
# 3/3 - 0s - 45ms/step - loss: 1.8507e-04 - val_loss: 8.1435e-05
# Epoch 258/500
# 3/3 - 0s - 46ms/step - loss: 2.3858e-04 - val_loss: 7.5245e-05
# Epoch 259/500
# 3/3 - 0s - 42ms/step - loss: 1.8762e-04 - val_loss: 7.2462e-05
# Epoch 260/500
# 3/3 - 0s - 42ms/step - loss: 1.5970e-04 - val_loss: 6.3024e-05
# Epoch 261/500
# 3/3 - 0s - 51ms/step - loss: 2.0175e-04 - val_loss: 9.0113e-05
# Epoch 262/500
# 3/3 - 0s - 39ms/step - loss: 1.7879e-04 - val_loss: 8.8598e-05
# Epoch 263/500
# 3/3 - 0s - 46ms/step - loss: 1.7563e-04 - val_loss: 6.2193e-05
# Epoch 264/500
# 3/3 - 0s - 39ms/step - loss: 1.5316e-04 - val_loss: 6.8378e-05
# Epoch 265/500
# 3/3 - 0s - 39ms/step - loss: 1.6151e-04 - val_loss: 6.1589e-05
# Epoch 266/500
# 3/3 - 0s - 45ms/step - loss: 1.1713e-04 - val_loss: 7.4164e-05
# Epoch 267/500
# 3/3 - 0s - 47ms/step - loss: 1.9400e-04 - val_loss: 7.2407e-05
# Epoch 268/500
# 3/3 - 0s - 38ms/step - loss: 2.1318e-04 - val_loss: 5.9706e-05
# Epoch 269/500
# 3/3 - 0s - 36ms/step - loss: 1.6443e-04 - val_loss: 6.1131e-05
# Epoch 270/500
# 3/3 - 0s - 40ms/step - loss: 1.3145e-04 - val_loss: 8.2710e-05
# Epoch 271/500
# 3/3 - 0s - 43ms/step - loss: 1.6678e-04 - val_loss: 7.8011e-05
# Epoch 272/500
# 3/3 - 0s - 47ms/step - loss: 1.1811e-04 - val_loss: 6.7241e-05
# Epoch 273/500
# 3/3 - 0s - 36ms/step - loss: 1.3131e-04 - val_loss: 6.4135e-05
# Epoch 274/500
# 3/3 - 0s - 48ms/step - loss: 1.1680e-04 - val_loss: 6.3541e-05
# Epoch 275/500
# 3/3 - 0s - 43ms/step - loss: 1.0489e-04 - val_loss: 7.3722e-05
# Epoch 276/500
# 3/3 - 0s - 35ms/step - loss: 1.7608e-04 - val_loss: 7.5840e-05
# Epoch 277/500
# 3/3 - 0s - 36ms/step - loss: 1.2497e-04 - val_loss: 6.7263e-05
# Epoch 278/500
# 3/3 - 0s - 47ms/step - loss: 1.6361e-04 - val_loss: 6.4121e-05
# Epoch 279/500
# 3/3 - 0s - 35ms/step - loss: 1.3125e-04 - val_loss: 6.3512e-05
# Epoch 280/500
# 3/3 - 0s - 35ms/step - loss: 1.4961e-04 - val_loss: 6.1501e-05
# Epoch 281/500
# 3/3 - 0s - 46ms/step - loss: 1.3959e-04 - val_loss: 6.4870e-05
# Epoch 282/500
# 3/3 - 0s - 35ms/step - loss: 1.7271e-04 - val_loss: 5.7070e-05
# Epoch 283/500
# 3/3 - 0s - 41ms/step - loss: 1.5140e-04 - val_loss: 5.2930e-05
# Epoch 284/500
# 3/3 - 0s - 40ms/step - loss: 1.6679e-04 - val_loss: 5.5148e-05
# Epoch 285/500
# 3/3 - 0s - 34ms/step - loss: 7.7749e-05 - val_loss: 6.0550e-05
# Epoch 286/500
# 3/3 - 0s - 48ms/step - loss: 1.4448e-04 - val_loss: 5.5656e-05
# Epoch 287/500
# 3/3 - 0s - 48ms/step - loss: 1.3622e-04 - val_loss: 5.5516e-05
# Epoch 288/500
# 3/3 - 0s - 36ms/step - loss: 1.1778e-04 - val_loss: 5.6989e-05
# Epoch 289/500
# 3/3 - 0s - 46ms/step - loss: 1.5653e-04 - val_loss: 6.0296e-05
# Epoch 290/500
# 3/3 - 0s - 36ms/step - loss: 1.1046e-04 - val_loss: 9.2101e-05
# Epoch 291/500
# 3/3 - 0s - 43ms/step - loss: 1.3201e-04 - val_loss: 1.1924e-04
# Epoch 292/500
# 3/3 - 0s - 40ms/step - loss: 2.0147e-04 - val_loss: 8.3569e-05
# Epoch 293/500
# 3/3 - 0s - 44ms/step - loss: 1.3349e-04 - val_loss: 7.2558e-05
# Epoch 294/500
# 3/3 - 0s - 52ms/step - loss: 1.4542e-04 - val_loss: 7.5988e-05
# Epoch 295/500
# 3/3 - 0s - 111ms/step - loss: 1.3211e-04 - val_loss: 9.3926e-05
# Epoch 296/500
# 3/3 - 0s - 103ms/step - loss: 1.8463e-04 - val_loss: 1.0385e-04
# Epoch 297/500
# 3/3 - 0s - 95ms/step - loss: 1.2420e-04 - val_loss: 8.8384e-05
# Epoch 298/500
# 3/3 - 0s - 68ms/step - loss: 1.8217e-04 - val_loss: 7.8707e-05
# Epoch 299/500
# 3/3 - 0s - 65ms/step - loss: 1.7610e-04 - val_loss: 7.0552e-05
# Epoch 300/500
# 3/3 - 0s - 98ms/step - loss: 1.6032e-04 - val_loss: 6.9092e-05
# Epoch 301/500
# 3/3 - 0s - 62ms/step - loss: 1.0052e-04 - val_loss: 7.4056e-05
# Epoch 302/500
# 3/3 - 0s - 65ms/step - loss: 2.0578e-04 - val_loss: 8.4063e-05
# Epoch 303/500
# 3/3 - 0s - 100ms/step - loss: 1.2452e-04 - val_loss: 5.9844e-05
# Epoch 304/500
# 3/3 - 0s - 108ms/step - loss: 1.1164e-04 - val_loss: 7.2284e-05
# Epoch 305/500
# 3/3 - 0s - 61ms/step - loss: 1.5806e-04 - val_loss: 5.5691e-05
# Epoch 306/500
# 3/3 - 0s - 70ms/step - loss: 1.6948e-04 - val_loss: 9.5916e-05
# Epoch 307/500
# 3/3 - 0s - 59ms/step - loss: 1.5418e-04 - val_loss: 1.1947e-04
# Epoch 308/500
# 3/3 - 0s - 64ms/step - loss: 1.5660e-04 - val_loss: 5.9210e-05
# Epoch 309/500
# 3/3 - 0s - 83ms/step - loss: 1.3139e-04 - val_loss: 6.7366e-05
# Epoch 310/500
# 3/3 - 0s - 93ms/step - loss: 1.9258e-04 - val_loss: 5.6496e-05
# Epoch 311/500
# 3/3 - 0s - 103ms/step - loss: 1.2834e-04 - val_loss: 6.7151e-05
# Epoch 312/500
# 3/3 - 0s - 99ms/step - loss: 1.1971e-04 - val_loss: 5.8428e-05
# Epoch 313/500
# 3/3 - 0s - 43ms/step - loss: 1.4092e-04 - val_loss: 5.6095e-05
# Epoch 314/500
# 3/3 - 0s - 40ms/step - loss: 1.4184e-04 - val_loss: 5.6151e-05
# Epoch 315/500
# 3/3 - 0s - 45ms/step - loss: 1.9495e-04 - val_loss: 5.3916e-05
# Epoch 316/500
# 3/3 - 0s - 46ms/step - loss: 1.0468e-04 - val_loss: 8.0569e-05
# Epoch 317/500
# 3/3 - 0s - 38ms/step - loss: 1.4064e-04 - val_loss: 6.3594e-05
# Epoch 318/500
# 3/3 - 0s - 47ms/step - loss: 1.0929e-04 - val_loss: 4.7979e-05
# Epoch 319/500
# 3/3 - 0s - 43ms/step - loss: 1.6748e-04 - val_loss: 7.0217e-05
# Epoch 320/500
# 3/3 - 0s - 39ms/step - loss: 1.5537e-04 - val_loss: 5.3895e-05
# Epoch 321/500
# 3/3 - 0s - 54ms/step - loss: 1.4162e-04 - val_loss: 5.6467e-05
# Epoch 322/500
# 3/3 - 0s - 38ms/step - loss: 2.1610e-04 - val_loss: 4.9641e-05
# Epoch 323/500
# 3/3 - 0s - 47ms/step - loss: 1.2891e-04 - val_loss: 5.9759e-05
# Epoch 324/500
# 3/3 - 0s - 46ms/step - loss: 9.0716e-05 - val_loss: 6.7851e-05
# Epoch 325/500
# 3/3 - 0s - 45ms/step - loss: 1.4326e-04 - val_loss: 6.0271e-05
# Epoch 326/500
# 3/3 - 0s - 51ms/step - loss: 1.2337e-04 - val_loss: 5.1735e-05
# Epoch 327/500
# 3/3 - 0s - 43ms/step - loss: 1.8402e-04 - val_loss: 5.9975e-05
# Epoch 328/500
# 3/3 - 0s - 53ms/step - loss: 8.6893e-05 - val_loss: 1.1208e-04
# Epoch 329/500
# 3/3 - 0s - 38ms/step - loss: 1.3379e-04 - val_loss: 1.0458e-04
# Epoch 330/500
# 3/3 - 0s - 47ms/step - loss: 1.4950e-04 - val_loss: 7.8353e-05
# Epoch 331/500
# 3/3 - 0s - 39ms/step - loss: 1.5635e-04 - val_loss: 6.7886e-05
# Epoch 332/500
# 3/3 - 0s - 37ms/step - loss: 1.0236e-04 - val_loss: 6.8039e-05
# Epoch 333/500
# 3/3 - 0s - 60ms/step - loss: 1.3861e-04 - val_loss: 6.8528e-05
# Epoch 334/500
# 3/3 - 0s - 86ms/step - loss: 1.7496e-04 - val_loss: 6.3075e-05
# Epoch 335/500
# 3/3 - 0s - 59ms/step - loss: 1.5618e-04 - val_loss: 6.0009e-05
# Epoch 336/500
# 3/3 - 0s - 37ms/step - loss: 1.5736e-04 - val_loss: 5.3576e-05
# Epoch 337/500
# 3/3 - 0s - 47ms/step - loss: 1.5519e-04 - val_loss: 7.6271e-05
# Epoch 338/500
# 3/3 - 0s - 36ms/step - loss: 1.3145e-04 - val_loss: 5.3378e-05
# Epoch 339/500
# 3/3 - 0s - 37ms/step - loss: 1.5089e-04 - val_loss: 5.0613e-05
# Epoch 340/500
# 3/3 - 0s - 42ms/step - loss: 9.1853e-05 - val_loss: 4.4939e-05
# Epoch 341/500
# 3/3 - 0s - 44ms/step - loss: 9.0709e-05 - val_loss: 4.0945e-05
# Epoch 342/500
# 3/3 - 0s - 51ms/step - loss: 1.3303e-04 - val_loss: 6.1181e-05
# Epoch 343/500
# 3/3 - 0s - 87ms/step - loss: 1.4575e-04 - val_loss: 4.2241e-05
# Epoch 344/500
# 3/3 - 0s - 38ms/step - loss: 1.3236e-04 - val_loss: 5.1627e-05
# Epoch 345/500
# 3/3 - 0s - 40ms/step - loss: 1.6588e-04 - val_loss: 4.5334e-05
# Epoch 346/500
# 3/3 - 0s - 40ms/step - loss: 8.5750e-05 - val_loss: 3.8655e-05
# Epoch 347/500
# 3/3 - 0s - 39ms/step - loss: 1.4090e-04 - val_loss: 8.1452e-05
# Epoch 348/500
# 3/3 - 0s - 46ms/step - loss: 1.6402e-04 - val_loss: 4.0991e-05
# Epoch 349/500
# 3/3 - 0s - 63ms/step - loss: 1.2427e-04 - val_loss: 3.7988e-05
# Epoch 350/500
# 3/3 - 0s - 85ms/step - loss: 1.6647e-04 - val_loss: 4.5747e-05
# Epoch 351/500
# 3/3 - 0s - 45ms/step - loss: 1.5106e-04 - val_loss: 3.8862e-05
# Epoch 352/500
# 3/3 - 0s - 38ms/step - loss: 1.2788e-04 - val_loss: 4.0321e-05
# Epoch 353/500
# 3/3 - 0s - 39ms/step - loss: 1.7647e-04 - val_loss: 5.3156e-05
# Epoch 354/500
# 3/3 - 0s - 37ms/step - loss: 9.4026e-05 - val_loss: 3.8175e-05
# Epoch 355/500
# 3/3 - 0s - 47ms/step - loss: 1.3084e-04 - val_loss: 3.9445e-05
# Epoch 356/500
# 3/3 - 0s - 47ms/step - loss: 1.0289e-04 - val_loss: 4.0446e-05
# Epoch 357/500
# 3/3 - 0s - 38ms/step - loss: 1.1696e-04 - val_loss: 4.9098e-05
# Epoch 358/500
# 3/3 - 0s - 38ms/step - loss: 1.1832e-04 - val_loss: 8.2007e-05
# Epoch 359/500
# 3/3 - 0s - 37ms/step - loss: 1.6818e-04 - val_loss: 5.1911e-05
# Epoch 360/500
# 3/3 - 0s - 38ms/step - loss: 7.6647e-05 - val_loss: 5.2647e-05
# Epoch 361/500
# 3/3 - 0s - 59ms/step - loss: 1.1669e-04 - val_loss: 4.8141e-05
# Epoch 362/500
# 3/3 - 0s - 50ms/step - loss: 9.3194e-05 - val_loss: 7.2634e-05
# Epoch 363/500
# 3/3 - 0s - 51ms/step - loss: 1.2025e-04 - val_loss: 7.0538e-05
# Epoch 364/500
# 3/3 - 0s - 37ms/step - loss: 1.6265e-04 - val_loss: 5.6694e-05
# Epoch 365/500
# 3/3 - 0s - 47ms/step - loss: 1.8921e-04 - val_loss: 7.0126e-05
# Epoch 366/500
# 3/3 - 0s - 46ms/step - loss: 1.1143e-04 - val_loss: 5.8281e-05
# Epoch 367/500
# 3/3 - 0s - 51ms/step - loss: 1.0085e-04 - val_loss: 5.5872e-05
# Epoch 368/500
# 3/3 - 0s - 38ms/step - loss: 9.4197e-05 - val_loss: 7.7134e-05
# Epoch 369/500
# 3/3 - 0s - 37ms/step - loss: 1.8277e-04 - val_loss: 4.5012e-05
# Epoch 370/500
# 3/3 - 0s - 39ms/step - loss: 1.1584e-04 - val_loss: 4.6356e-05
# Epoch 371/500
# 3/3 - 0s - 42ms/step - loss: 1.7539e-04 - val_loss: 3.9149e-05
# Epoch 372/500
# 3/3 - 0s - 37ms/step - loss: 1.4477e-04 - val_loss: 4.1277e-05
# Epoch 373/500
# 3/3 - 0s - 39ms/step - loss: 8.4846e-05 - val_loss: 3.6762e-05
# Epoch 374/500
# 3/3 - 0s - 37ms/step - loss: 9.3370e-05 - val_loss: 2.9316e-05
# Epoch 375/500
# 3/3 - 0s - 39ms/step - loss: 1.2827e-04 - val_loss: 2.9540e-05
# Epoch 376/500
# 3/3 - 0s - 43ms/step - loss: 9.0760e-05 - val_loss: 2.8720e-05
# Epoch 377/500
# 3/3 - 0s - 46ms/step - loss: 9.9589e-05 - val_loss: 4.2282e-05
# Epoch 378/500
# 3/3 - 0s - 37ms/step - loss: 1.0169e-04 - val_loss: 5.6041e-05
# Epoch 379/500
# 3/3 - 0s - 42ms/step - loss: 1.3761e-04 - val_loss: 3.3253e-05
# Epoch 380/500
# 3/3 - 0s - 55ms/step - loss: 1.1147e-04 - val_loss: 4.9296e-05
# Epoch 381/500
# 3/3 - 0s - 39ms/step - loss: 1.6917e-04 - val_loss: 3.9950e-05
# Epoch 382/500
# 3/3 - 0s - 45ms/step - loss: 1.3066e-04 - val_loss: 4.3903e-05
# Epoch 383/500
# 3/3 - 0s - 40ms/step - loss: 8.7455e-05 - val_loss: 5.0893e-05
# Epoch 384/500
# 3/3 - 0s - 72ms/step - loss: 1.3039e-04 - val_loss: 3.5930e-05
# Epoch 385/500
# 3/3 - 0s - 68ms/step - loss: 1.1216e-04 - val_loss: 4.2252e-05
# Epoch 386/500
# 3/3 - 0s - 97ms/step - loss: 1.1495e-04 - val_loss: 3.3097e-05
# Epoch 387/500
# 3/3 - 0s - 91ms/step - loss: 8.1591e-05 - val_loss: 4.7462e-05
# Epoch 388/500
# 3/3 - 0s - 102ms/step - loss: 1.7223e-04 - val_loss: 4.9709e-05
# Epoch 389/500
# 3/3 - 0s - 107ms/step - loss: 9.9037e-05 - val_loss: 3.4734e-05
# Epoch 390/500
# 3/3 - 0s - 53ms/step - loss: 1.1517e-04 - val_loss: 3.7409e-05
# Epoch 391/500
# 3/3 - 0s - 56ms/step - loss: 1.1075e-04 - val_loss: 3.7707e-05
# Epoch 392/500
# 3/3 - 0s - 61ms/step - loss: 1.2354e-04 - val_loss: 3.8125e-05
# Epoch 393/500
# 3/3 - 0s - 55ms/step - loss: 1.3673e-04 - val_loss: 3.2440e-05
# Epoch 394/500
# 3/3 - 0s - 106ms/step - loss: 1.4482e-04 - val_loss: 4.9326e-05
# Epoch 395/500
# 3/3 - 0s - 69ms/step - loss: 9.1311e-05 - val_loss: 4.5537e-05
# Epoch 396/500
# 3/3 - 0s - 95ms/step - loss: 1.2530e-04 - val_loss: 2.9923e-05
# Epoch 397/500
# 3/3 - 0s - 91ms/step - loss: 1.1221e-04 - val_loss: 4.9542e-05
# Epoch 398/500
# 3/3 - 0s - 67ms/step - loss: 1.5523e-04 - val_loss: 2.7152e-05
# Epoch 399/500
# 3/3 - 0s - 106ms/step - loss: 9.6045e-05 - val_loss: 6.0001e-05
# Epoch 400/500
# 3/3 - 0s - 84ms/step - loss: 1.7415e-04 - val_loss: 3.9684e-05
# Epoch 401/500
# 3/3 - 0s - 67ms/step - loss: 1.0855e-04 - val_loss: 2.8351e-05
# Epoch 402/500
# 3/3 - 0s - 100ms/step - loss: 8.6283e-05 - val_loss: 4.6819e-05
# Epoch 403/500
# 3/3 - 0s - 75ms/step - loss: 1.3906e-04 - val_loss: 5.6247e-05
# Epoch 404/500
# 3/3 - 0s - 46ms/step - loss: 1.0208e-04 - val_loss: 3.0368e-05
# Epoch 405/500
# 3/3 - 0s - 45ms/step - loss: 1.4017e-04 - val_loss: 4.1057e-05
# Epoch 406/500
# 3/3 - 0s - 35ms/step - loss: 1.0021e-04 - val_loss: 2.4190e-05
# Epoch 407/500
# 3/3 - 0s - 47ms/step - loss: 5.6333e-05 - val_loss: 6.1546e-05
# Epoch 408/500
# 3/3 - 0s - 40ms/step - loss: 1.3114e-04 - val_loss: 2.4716e-05
# Epoch 409/500
# 3/3 - 0s - 35ms/step - loss: 1.2737e-04 - val_loss: 4.8731e-05
# Epoch 410/500
# 3/3 - 0s - 36ms/step - loss: 1.2005e-04 - val_loss: 2.1254e-05
# Epoch 411/500
# 3/3 - 0s - 39ms/step - loss: 9.9954e-05 - val_loss: 3.0842e-05
# Epoch 412/500
# 3/3 - 0s - 35ms/step - loss: 9.4458e-05 - val_loss: 3.8549e-05
# Epoch 413/500
# 3/3 - 0s - 35ms/step - loss: 2.0134e-04 - val_loss: 1.6999e-05
# Epoch 414/500
# 3/3 - 0s - 35ms/step - loss: 1.6370e-04 - val_loss: 2.9465e-05
# Epoch 415/500
# 3/3 - 0s - 48ms/step - loss: 8.4924e-05 - val_loss: 1.7754e-05
# Epoch 416/500
# 3/3 - 0s - 59ms/step - loss: 1.0659e-04 - val_loss: 3.8993e-05
# Epoch 417/500
# 3/3 - 0s - 35ms/step - loss: 1.0814e-04 - val_loss: 2.6816e-05
# Epoch 418/500
# 3/3 - 0s - 36ms/step - loss: 1.1650e-04 - val_loss: 1.9942e-05
# Epoch 419/500
# 3/3 - 0s - 40ms/step - loss: 1.1786e-04 - val_loss: 4.9385e-05
# Epoch 420/500
# 3/3 - 0s - 36ms/step - loss: 1.0385e-04 - val_loss: 3.4636e-05
# Epoch 421/500
# 3/3 - 0s - 61ms/step - loss: 1.1285e-04 - val_loss: 2.7174e-05
# Epoch 422/500
# 3/3 - 0s - 37ms/step - loss: 9.4137e-05 - val_loss: 3.1542e-05
# Epoch 423/500
# 3/3 - 0s - 35ms/step - loss: 1.4452e-04 - val_loss: 4.2694e-05
# Epoch 424/500
# 3/3 - 0s - 51ms/step - loss: 1.3428e-04 - val_loss: 4.5475e-05
# Epoch 425/500
# 3/3 - 0s - 42ms/step - loss: 1.4984e-04 - val_loss: 3.7194e-05
# Epoch 426/500
# 3/3 - 0s - 50ms/step - loss: 1.8863e-04 - val_loss: 3.9773e-05
# Epoch 427/500
# 3/3 - 0s - 44ms/step - loss: 1.3588e-04 - val_loss: 3.7031e-05
# Epoch 428/500
# 3/3 - 0s - 47ms/step - loss: 8.8501e-05 - val_loss: 3.2148e-05
# Epoch 429/500
# 3/3 - 0s - 35ms/step - loss: 1.2352e-04 - val_loss: 2.7707e-05
# Epoch 430/500
# 3/3 - 0s - 36ms/step - loss: 1.0371e-04 - val_loss: 2.5879e-05
# Epoch 431/500
# 3/3 - 0s - 36ms/step - loss: 1.1180e-04 - val_loss: 5.3358e-05
# Epoch 432/500
# 3/3 - 0s - 41ms/step - loss: 1.2364e-04 - val_loss: 4.2647e-05
# Epoch 433/500
# 3/3 - 0s - 44ms/step - loss: 1.5714e-04 - val_loss: 3.7846e-05
# Epoch 434/500
# 3/3 - 0s - 39ms/step - loss: 1.2990e-04 - val_loss: 4.2514e-05
# Epoch 435/500
# 3/3 - 0s - 35ms/step - loss: 1.3570e-04 - val_loss: 1.9137e-05
# Epoch 436/500
# 3/3 - 0s - 46ms/step - loss: 1.1468e-04 - val_loss: 4.2599e-05
# Epoch 437/500
# 3/3 - 0s - 36ms/step - loss: 1.3048e-04 - val_loss: 1.9837e-05
# Epoch 438/500
# 3/3 - 0s - 35ms/step - loss: 9.6616e-05 - val_loss: 2.1626e-05
# Epoch 439/500
# 3/3 - 0s - 49ms/step - loss: 1.3636e-04 - val_loss: 2.0645e-05
# Epoch 440/500
# 3/3 - 0s - 57ms/step - loss: 8.1687e-05 - val_loss: 2.1974e-05
# Epoch 441/500
# 3/3 - 0s - 51ms/step - loss: 6.1433e-05 - val_loss: 2.4023e-05
# Epoch 442/500
# 3/3 - 0s - 38ms/step - loss: 1.2888e-04 - val_loss: 2.6199e-05
# Epoch 443/500
# 3/3 - 0s - 58ms/step - loss: 9.2855e-05 - val_loss: 3.5190e-05
# Epoch 444/500
# 3/3 - 0s - 37ms/step - loss: 1.5331e-04 - val_loss: 3.8501e-05
# Epoch 445/500
# 3/3 - 0s - 47ms/step - loss: 9.1582e-05 - val_loss: 2.7106e-05
# Epoch 446/500
# 3/3 - 0s - 37ms/step - loss: 9.7477e-05 - val_loss: 2.7529e-05
# Epoch 447/500
# 3/3 - 0s - 51ms/step - loss: 1.0273e-04 - val_loss: 2.6932e-05
# Epoch 448/500
# 3/3 - 0s - 51ms/step - loss: 8.9018e-05 - val_loss: 2.5871e-05
# Epoch 449/500
# 3/3 - 0s - 38ms/step - loss: 1.1844e-04 - val_loss: 2.9351e-05
# Epoch 450/500
# 3/3 - 0s - 45ms/step - loss: 7.4408e-05 - val_loss: 2.0025e-05
# Epoch 451/500
# 3/3 - 0s - 37ms/step - loss: 1.3902e-04 - val_loss: 3.3389e-05
# Epoch 452/500
# 3/3 - 0s - 38ms/step - loss: 8.8518e-05 - val_loss: 6.3617e-05
# Epoch 453/500
# 3/3 - 0s - 44ms/step - loss: 2.2352e-04 - val_loss: 1.9276e-05
# Epoch 454/500
# 3/3 - 0s - 38ms/step - loss: 1.4601e-04 - val_loss: 3.8072e-05
# Epoch 455/500
# 3/3 - 0s - 42ms/step - loss: 1.4354e-04 - val_loss: 2.2295e-05
# Epoch 456/500
# 3/3 - 0s - 41ms/step - loss: 1.1195e-04 - val_loss: 5.5053e-05
# Epoch 457/500
# 3/3 - 0s - 37ms/step - loss: 1.4785e-04 - val_loss: 3.8406e-05
# Epoch 458/500
# 3/3 - 0s - 37ms/step - loss: 1.3577e-04 - val_loss: 1.7145e-05
# Epoch 459/500
# 3/3 - 0s - 47ms/step - loss: 9.3741e-05 - val_loss: 1.8881e-05
# Epoch 460/500
# 3/3 - 0s - 38ms/step - loss: 1.3054e-04 - val_loss: 2.7635e-05
# Epoch 461/500
# 3/3 - 0s - 37ms/step - loss: 1.0859e-04 - val_loss: 2.3173e-05
# Epoch 462/500
# 3/3 - 0s - 47ms/step - loss: 1.2900e-04 - val_loss: 4.1391e-05
# Epoch 463/500
# 3/3 - 0s - 41ms/step - loss: 1.3589e-04 - val_loss: 2.0296e-05
# Epoch 464/500
# 3/3 - 0s - 53ms/step - loss: 7.7606e-05 - val_loss: 3.0245e-05
# Epoch 465/500
# 3/3 - 0s - 37ms/step - loss: 7.9783e-05 - val_loss: 2.8212e-05
# Epoch 466/500
# 3/3 - 0s - 48ms/step - loss: 1.2569e-04 - val_loss: 2.0184e-05
# Epoch 467/500
# 3/3 - 0s - 46ms/step - loss: 1.3796e-04 - val_loss: 2.7638e-05
# Epoch 468/500
# 3/3 - 0s - 38ms/step - loss: 1.1711e-04 - val_loss: 1.7332e-05
# Epoch 469/500
# 3/3 - 0s - 38ms/step - loss: 9.4576e-05 - val_loss: 3.9884e-05
# Epoch 470/500
# 3/3 - 0s - 37ms/step - loss: 1.0615e-04 - val_loss: 1.8660e-05
# Epoch 471/500
# 3/3 - 0s - 55ms/step - loss: 1.4468e-04 - val_loss: 2.3807e-05
# Epoch 472/500
# 3/3 - 0s - 81ms/step - loss: 1.1026e-04 - val_loss: 2.2194e-05
# Epoch 473/500
# 3/3 - 0s - 45ms/step - loss: 1.1480e-04 - val_loss: 4.3036e-05
# Epoch 474/500
# 3/3 - 0s - 60ms/step - loss: 1.1374e-04 - val_loss: 2.0485e-05
# Epoch 475/500
# 3/3 - 0s - 99ms/step - loss: 1.0616e-04 - val_loss: 2.8458e-05
# Epoch 476/500
# 3/3 - 0s - 64ms/step - loss: 2.0375e-04 - val_loss: 3.6400e-05
# Epoch 477/500
# 3/3 - 0s - 67ms/step - loss: 1.3163e-04 - val_loss: 1.0044e-04
# Epoch 478/500
# 3/3 - 0s - 98ms/step - loss: 1.3485e-04 - val_loss: 3.7734e-05
# Epoch 479/500
# 3/3 - 0s - 64ms/step - loss: 1.5533e-04 - val_loss: 4.8729e-05
# Epoch 480/500
# 3/3 - 0s - 57ms/step - loss: 1.0789e-04 - val_loss: 3.2948e-05
# Epoch 481/500
# 3/3 - 0s - 107ms/step - loss: 9.4030e-05 - val_loss: 3.0230e-05
# Epoch 482/500
# 3/3 - 0s - 100ms/step - loss: 1.1856e-04 - val_loss: 2.1119e-05
# Epoch 483/500
# 3/3 - 0s - 63ms/step - loss: 8.9270e-05 - val_loss: 2.6444e-05
# Epoch 484/500
# 3/3 - 0s - 105ms/step - loss: 9.9442e-05 - val_loss: 1.4551e-05
# Epoch 485/500
# 3/3 - 0s - 55ms/step - loss: 1.6453e-04 - val_loss: 1.3237e-05
# Epoch 486/500
# 3/3 - 0s - 117ms/step - loss: 1.3257e-04 - val_loss: 1.8439e-05
# Epoch 487/500
# 3/3 - 0s - 70ms/step - loss: 1.2314e-04 - val_loss: 1.4697e-05
# Epoch 488/500
# 3/3 - 0s - 69ms/step - loss: 1.4295e-04 - val_loss: 1.5443e-05
# Epoch 489/500
# 3/3 - 0s - 65ms/step - loss: 1.2572e-04 - val_loss: 1.6925e-05
# Epoch 490/500
# 3/3 - 0s - 69ms/step - loss: 1.0673e-04 - val_loss: 1.6596e-05
# Epoch 491/500
# 3/3 - 0s - 68ms/step - loss: 1.5693e-04 - val_loss: 1.6950e-05
# Epoch 492/500
# 3/3 - 0s - 65ms/step - loss: 8.5674e-05 - val_loss: 1.8968e-05
# Epoch 493/500
# 3/3 - 0s - 105ms/step - loss: 1.1366e-04 - val_loss: 1.8151e-05
# Epoch 494/500
# 3/3 - 0s - 97ms/step - loss: 8.1951e-05 - val_loss: 1.8283e-05
# Epoch 495/500
# 3/3 - 0s - 71ms/step - loss: 9.9055e-05 - val_loss: 1.9313e-05
# Epoch 496/500
# 3/3 - 0s - 47ms/step - loss: 7.1024e-05 - val_loss: 3.0324e-05
# Epoch 497/500
# 3/3 - 0s - 38ms/step - loss: 1.2028e-04 - val_loss: 1.6375e-05
# Epoch 498/500
# 3/3 - 0s - 44ms/step - loss: 1.1886e-04 - val_loss: 3.5158e-05
# Epoch 499/500
# 3/3 - 0s - 48ms/step - loss: 1.5218e-04 - val_loss: 2.4149e-05
# Epoch 500/500
# 3/3 - 0s - 46ms/step - loss: 8.8210e-05 - val_loss: 1.6611e-05

# %% [markdown]
# ##Hasil Prediksi

# %%
# Make a prediction

# Kode untuk data pelatihan (train data)
# Make a prediction for training data
xhat = best_model.predict(train_X)

# Invert scaling for forecast (training data)
inv_xhat = np.concatenate((xhat, train_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_xhat = scaler.inverse_transform(inv_xhat.reshape(-1, inv_xhat.shape[-1]))  # Flatten then inverse transform
inv_xhat = inv_xhat[:,0]

# Invert scaling for actual (training data)
train_y = train_y.reshape((len(train_y), 1))
inv_x = np.concatenate((train_y, train_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_x = scaler.inverse_transform(inv_x.reshape(-1, inv_x.shape[-1]))  # Flatten then inverse transform
inv_x = inv_x[:,0]

# Kode untuk data pelatihan (test data)
# Make a prediction for test data
yhat = best_model.predict(test_X)

# Invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat.reshape(-1, inv_yhat.shape[-1]))  # Flatten then inverse transform
inv_yhat = inv_yhat[:,0]

# Invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_y = scaler.inverse_transform(inv_y.reshape(-1, inv_y.shape[-1]))  # Flatten then inverse transform
inv_y = inv_y[:,0]

# Calculate RMSE for training data
train_rmse = np.sqrt(mean_squared_error(inv_x, inv_xhat))
print('Train RMSE: %.3f' % train_rmse)

# Calculate MAPE for training data
train_mape = mean_absolute_percentage_error(inv_x, inv_xhat)
print('Train MAPE: %.3f' % train_mape)


# Calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)

# Calculate MAPE
mape = mean_absolute_percentage_error(inv_y, inv_yhat)
print('Test MAPE: %.3f' % mape)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Train RMSE: 0.749
# Train MAPE: 0.012
# Test RMSE: 1.446
# Test MAPE: 0.007

# %%
## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 200 hours.

# Adjust the range of aa to match the length of inv_y and inv_yhat


aa=[x for x in range(len(inv_x))] # Change this line

plt.plot(aa, inv_x, marker='.', label="actual") # Remove slicing [:200]
plt.plot(aa, inv_xhat, 'r', label="prediction") # Remove slicing [:200]
plt.title('Model Performance Data train')
plt.ylabel('Jumlah Pengunjung', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# Adjust the range of aa to match the length of inv_y and inv_yhat
aa=[x for x in range(len(inv_y))] # Change this line

plt.plot(aa, inv_y, marker='.', label="actual") # Remove slicing [:200]
plt.plot(aa, inv_yhat, 'r', label="prediction") # Remove slicing [:200]
plt.title('Model Performance Data test')
plt.ylabel('Jumlah Pengunjung', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()
