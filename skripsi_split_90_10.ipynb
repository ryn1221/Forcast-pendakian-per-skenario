# %% [markdown]
# <a href="https://colab.research.google.com/github/ryn1221/Forcast-pendakian-per-skenario/blob/main/skripsi_split_90_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Persiapan Data & library

# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade scikeras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.3.1
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.3.1
#   Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (3.5.0)
# Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 37.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikeras 0.13.0 requires scikit-learn>=1.4.2, but you have scikit-learn 1.3.1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.3.1 which is incompatible.
# Successfully installed scikit-learn-1.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph
import seaborn as sns # used for plot interactive graph.

import itertools

# %%
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from tensorflow import keras
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from tensorflow import keras # Import keras this way
from keras.utils import to_categorical

# %%
from keras.layers import LSTM, Conv1D, MaxPooling1D, Dropout

# %%
pred_data = pd.read_csv('/content/drive/MyDrive/TA/dataset/REGISTER PENJUALAN KARCIS THN 2022 WANA WISATA GUNUNG PANDERMAN RPH ORO - ORO OMBO BKPH PUJON.csv')
#pred_data.set_index('Date', inplace=True)

pred_data.drop("Unnamed: 8", axis=1, inplace=True)
pred_data.drop("Unnamed: 9", axis=1, inplace=True)

# %%
pred_data.head()
# Out:
#          Date SERI  NO. AWAL   NO. AKHIR  JUMLAH TERJUAL   HARGA KARCIS   \
# 0  2022-01-01    B     5017.0     5516.0            500.0        15000.0
# 1  2022-01-02    B     5517.0     5641.0            125.0        15000.0
# 2  2022-01-03    B     5642.0     5757.0            116.0        15000.0
# 3  2022-01-04    B     5758.0     5882.0            125.0        15000.0
# 4  2022-01-05    B     5883.0     5932.0             50.0        15000.0
#
#    JUMLAH PENDAPATAN KETERANGAN
# 0          7500000.0        NaN
# 1          1875000.0        NaN
# 2          1740000.0        NaN
# 3          1875000.0        NaN
# 4           750000.0        NaN

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               730 non-null    object
#  1   SERI               560 non-null    object
#  2   NO. AWAL           560 non-null    float64
#  3   NO. AKHIR          560 non-null    float64
#  4   JUMLAH TERJUAL     560 non-null    float64
#  5   HARGA KARCIS       560 non-null    float64
#  6   JUMLAH PENDAPATAN  560 non-null    float64
#  7   KETERANGAN         33 non-null     object
# dtypes: float64(5), object(3)
# memory usage: 45.8+ KB

# %%
pred_data.shape
# Out:
# (730, 8)

# %%
pred_data.describe()
# Out:
#           NO. AWAL      NO. AKHIR  JUMLAH TERJUAL   HARGA KARCIS   \
# count    560.000000    560.000000       560.000000          560.0
# mean    4592.346429   4700.237500       108.891071        15000.0
# std     3184.044205   3198.082791       133.205548            0.0
# min        1.000000      4.000000         2.000000        15000.0
# 25%     1707.000000   1768.500000        23.750000        15000.0
# 50%     4058.500000   4206.500000        60.000000        15000.0
# 75%     7335.000000   7429.500000       140.000000        15000.0
# max    10600.000000  10738.000000      1154.000000        15000.0
#
#        JUMLAH PENDAPATAN
# count       5.600000e+02
# mean        1.633366e+06
# std         1.998083e+06
# min         3.000000e+04
# 25%         3.562500e+05
# 50%         9.000000e+05
# 75%         2.100000e+06
# max         1.731000e+07

# %% [markdown]
# #Prep Data

# %%
pred_data.columns=pred_data.columns.str.replace(" ","").str.lower()
pred_data.columns=pred_data.columns.str.replace(".","_").str.lower()

# %%
pred_data=pred_data.drop(columns=['seri', 'no_awal', 'no_akhir','hargakarcis','keterangan'])

# %%
print("Shape of the dataset: ", pred_data.shape)
print("Length of the dataset: ", len(pred_data))
print("Jumlah tiket paling banyak terjual dalam satu hari : ", pred_data["jumlahterjual"].max())
print("Jumlah tiket paling sedikt terjual dalam satu hari : ", pred_data["jumlahterjual"].min())
# Out:
# Shape of the dataset:  (730, 3)
# Length of the dataset:  730
# Jumlah tiket paling banyak terjual dalam satu hari :  1154.0
# Jumlah tiket paling sedikt terjual dalam satu hari :  2.0

# %%
# Convert the 'date' column to datetime objects
pred_data['date'] = pd.to_datetime(pred_data['date'])

# %%
fig = plt.subplots( figsize = (25, 15))

sns.distplot( x = pred_data["jumlahterjual"], hist = True,
             bins = 10, kde = True,).set(title = "distribusi penjualan tiket");
# Out:
# <ipython-input-20-1dee3892c34c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x = pred_data["jumlahterjual"], hist = True,

# %%
sns.set(rc = {"figure.facecolor":"#ffffff"})

fig = plt.subplots( figsize = (25, 10))

sns.lineplot( x = pred_data["date"], y = pred_data["jumlahterjual"]);

# %%
sns.jointplot(x = "date", y = "jumlahterjual", data = pred_data, height = 8, ratio = 6, kind = "scatter");

# %%
fig = plt.figure(figsize = (15, 10))

plt.plot(pred_data["date"], pred_data["jumlahterjual"], color = "#0E7791")
plt.title("jumlah pengunjung berdasarkan tiket terjual periode 1 januari 2022 - 31 desember 2023")
plt.xlabel("date", fontsize = 15)
plt.ylabel("jumlah tiket terjual", fontsize = 15)
plt.show()

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,3):
    if not pred_data.iloc[:, j].notnull().all():
        droping_list_all.append(j)

droping_list_all
# Out:
# [1, 2]

# %%
#mengisi nilai kosong dengan interpolasi liniear
for j in range(1,3):
    pred_data.iloc[:,j] = pred_data.iloc[:,j].interpolate(method='linear')

# %%
pred_data.isnull().sum()
# Out:
# date                0
# jumlahterjual       0
# jumlahpendapatan    0
# dtype: int64

# %%
pred_data
# Out:
#           date  jumlahterjual  jumlahpendapatan
# 0   2022-01-01          500.0         7500000.0
# 1   2022-01-02          125.0         1875000.0
# 2   2022-01-03          116.0         1740000.0
# 3   2022-01-04          125.0         1875000.0
# 4   2022-01-05           50.0          750000.0
# ..         ...            ...               ...
# 725 2023-12-27           16.0          240000.0
# 726 2023-12-28           14.0          210000.0
# 727 2023-12-29           26.0          390000.0
# 728 2023-12-30          250.0         3750000.0
# 729 2023-12-31          300.0         4500000.0
#
# [730 rows x 3 columns]

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    datetime64[ns]
#  1   jumlahterjual     730 non-null    float64
#  2   jumlahpendapatan  730 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 17.2 KB

# %% [markdown]
# #Pemodelan

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	dff = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(dff.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(dff.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# Convert 'date' column to datetime objects and set it as the index
pred_data.set_index('date', inplace=True)

#resample data
df_resample = pred_data.resample('W').mean()
df_resample.shape
# Out:
# (105, 2)

# %%
pred_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 730 entries, 2022-01-01 to 2023-12-31
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jumlahterjual     730 non-null    float64
#  1   jumlahpendapatan  730 non-null    float64
# dtypes: float64(2)
# memory usage: 17.1 KB

# %% [markdown]
# ##Normalisasi

# %%
values = df_resample.values

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop unnecessary columns
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)   var1(t)   var2(t)
# 1   0.862118   0.862118  0.450886  0.450886
# 2   0.450886   0.450886  0.363124  0.363124
# 3   0.363124   0.363124  0.283816  0.283816
# 4   0.283816   0.283816  0.265298  0.265298
# 5   0.265298   0.265298  0.195652  0.195652

# %% [markdown]
# ##Split Data 90:10

# %%
# split train dan test sets
values = reframed.values

n_train_time = int(len(values) * 0.9)  # data train 90%
train = values[:n_train_time, :]
test = values[n_train_time:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# We reshaped the input into the 3D format as expected by LSTMs, namely [samples, timesteps, features].
# Out:
# (93, 1, 3) (93,) (11, 1, 3) (11,)

# %% [markdown]
# ##Model LSTM

# %%
# Fungsi untuk membuat model LSTM tanpa default parameter
def create_model(neurons, dropout_rate):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))  # Output layer
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# Membungkus model dengan KerasRegressor agar bisa digunakan dalam GridSearchCV
model = KerasRegressor(build_fn=create_model, verbose=0)

# Mendefinisikan parameter grid untuk pencarian GridSearch
param_grid = {
    'epochs': [200, 300, 500],  # Nilai epoch yang ingin diuji
    'batch_size': [32, 64, 128],  # Nilai batch size yang ingin diuji
    'model__neurons': [64, 128, 256],  # Jumlah neuron di LSTM layer, note 'model__' prefix
    'model__dropout_rate': [0.2, 0.3, 0.4]  # Dropout rate yang ingin diuji, note 'model__' prefix
}


# Menggunakan GridSearchCV untuk mencari parameter terbaik
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(train_X, train_y)

# Menampilkan hasil terbaik
print(f'Best score: {grid_result.best_score_}')
print(f'Best parameters: {grid_result.best_params_}')

# Dapatkan parameter terbaik
best_epochs = grid_result.best_params_['epochs']
best_batch_size = grid_result.best_params_['batch_size']
best_neurons = grid_result.best_params_['model__neurons']  # Access using 'model__neurons'
best_dropout_rate = grid_result.best_params_['model__dropout_rate']  # Access using 'model__dropout_rate'

# Membuat model dengan parameter terbaik yang ditemukan
best_model = create_model(neurons=best_neurons, dropout_rate=best_dropout_rate)

# Fit model dengan parameter terbaik
history = best_model.fit(train_X, train_y, epochs=best_epochs, batch_size=best_batch_size, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
# Out:
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Best score: 0.9987596267314872
# Best parameters: {'batch_size': 32, 'epochs': 500, 'model__dropout_rate': 0.4, 'model__neurons': 256}
# Epoch 1/500
# 3/3 - 3s - 909ms/step - loss: 0.1046 - val_loss: 0.0642
# Epoch 2/500
# 3/3 - 0s - 117ms/step - loss: 0.0875 - val_loss: 0.0501
# Epoch 3/500
# 3/3 - 0s - 48ms/step - loss: 0.0704 - val_loss: 0.0379
# Epoch 4/500
# 3/3 - 0s - 37ms/step - loss: 0.0591 - val_loss: 0.0277
# Epoch 5/500
# 3/3 - 0s - 47ms/step - loss: 0.0463 - val_loss: 0.0195
# Epoch 6/500
# 3/3 - 0s - 46ms/step - loss: 0.0366 - val_loss: 0.0133
# Epoch 7/500
# 3/3 - 0s - 47ms/step - loss: 0.0282 - val_loss: 0.0090
# Epoch 8/500
# 3/3 - 0s - 37ms/step - loss: 0.0237 - val_loss: 0.0065
# Epoch 9/500
# 3/3 - 0s - 37ms/step - loss: 0.0201 - val_loss: 0.0057
# Epoch 10/500
# 3/3 - 0s - 46ms/step - loss: 0.0175 - val_loss: 0.0059
# Epoch 11/500
# 3/3 - 0s - 44ms/step - loss: 0.0190 - val_loss: 0.0068
# Epoch 12/500
# 3/3 - 0s - 38ms/step - loss: 0.0178 - val_loss: 0.0076
# Epoch 13/500
# 3/3 - 0s - 37ms/step - loss: 0.0190 - val_loss: 0.0081
# Epoch 14/500
# 3/3 - 0s - 38ms/step - loss: 0.0184 - val_loss: 0.0082
# Epoch 15/500
# 3/3 - 0s - 59ms/step - loss: 0.0180 - val_loss: 0.0077
# Epoch 16/500
# 3/3 - 0s - 37ms/step - loss: 0.0180 - val_loss: 0.0070
# Epoch 17/500
# 3/3 - 0s - 37ms/step - loss: 0.0160 - val_loss: 0.0063
# Epoch 18/500
# 3/3 - 0s - 35ms/step - loss: 0.0159 - val_loss: 0.0056
# Epoch 19/500
# 3/3 - 0s - 63ms/step - loss: 0.0158 - val_loss: 0.0052
# Epoch 20/500
# 3/3 - 0s - 84ms/step - loss: 0.0160 - val_loss: 0.0048
# Epoch 21/500
# 3/3 - 0s - 47ms/step - loss: 0.0148 - val_loss: 0.0046
# Epoch 22/500
# 3/3 - 0s - 45ms/step - loss: 0.0149 - val_loss: 0.0044
# Epoch 23/500
# 3/3 - 0s - 36ms/step - loss: 0.0139 - val_loss: 0.0043
# Epoch 24/500
# 3/3 - 0s - 36ms/step - loss: 0.0127 - val_loss: 0.0041
# Epoch 25/500
# 3/3 - 0s - 53ms/step - loss: 0.0131 - val_loss: 0.0040
# Epoch 26/500
# 3/3 - 0s - 41ms/step - loss: 0.0124 - val_loss: 0.0039
# Epoch 27/500
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0038
# Epoch 28/500
# 3/3 - 0s - 39ms/step - loss: 0.0120 - val_loss: 0.0037
# Epoch 29/500
# 3/3 - 0s - 38ms/step - loss: 0.0122 - val_loss: 0.0036
# Epoch 30/500
# 3/3 - 0s - 46ms/step - loss: 0.0123 - val_loss: 0.0035
# Epoch 31/500
# 3/3 - 0s - 45ms/step - loss: 0.0106 - val_loss: 0.0034
# Epoch 32/500
# 3/3 - 0s - 66ms/step - loss: 0.0107 - val_loss: 0.0033
# Epoch 33/500
# 3/3 - 0s - 81ms/step - loss: 0.0104 - val_loss: 0.0032
# Epoch 34/500
# 3/3 - 0s - 48ms/step - loss: 0.0103 - val_loss: 0.0031
# Epoch 35/500
# 3/3 - 0s - 36ms/step - loss: 0.0095 - val_loss: 0.0030
# Epoch 36/500
# 3/3 - 0s - 47ms/step - loss: 0.0084 - val_loss: 0.0028
# Epoch 37/500
# 3/3 - 0s - 36ms/step - loss: 0.0086 - val_loss: 0.0027
# Epoch 38/500
# 3/3 - 0s - 35ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 39/500
# 3/3 - 0s - 40ms/step - loss: 0.0082 - val_loss: 0.0025
# Epoch 40/500
# 3/3 - 0s - 38ms/step - loss: 0.0087 - val_loss: 0.0023
# Epoch 41/500
# 3/3 - 0s - 46ms/step - loss: 0.0075 - val_loss: 0.0022
# Epoch 42/500
# 3/3 - 0s - 46ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 43/500
# 3/3 - 0s - 47ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 44/500
# 3/3 - 0s - 36ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 45/500
# 3/3 - 0s - 46ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 46/500
# 3/3 - 0s - 36ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 47/500
# 3/3 - 0s - 52ms/step - loss: 0.0058 - val_loss: 0.0015
# Epoch 48/500
# 3/3 - 0s - 42ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 49/500
# 3/3 - 0s - 45ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 50/500
# 3/3 - 0s - 36ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 51/500
# 3/3 - 0s - 36ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 52/500
# 3/3 - 0s - 47ms/step - loss: 0.0034 - val_loss: 0.0010
# Epoch 53/500
# 3/3 - 0s - 36ms/step - loss: 0.0035 - val_loss: 9.3219e-04
# Epoch 54/500
# 3/3 - 0s - 37ms/step - loss: 0.0033 - val_loss: 8.6470e-04
# Epoch 55/500
# 3/3 - 0s - 45ms/step - loss: 0.0027 - val_loss: 7.9189e-04
# Epoch 56/500
# 3/3 - 0s - 37ms/step - loss: 0.0030 - val_loss: 7.1645e-04
# Epoch 57/500
# 3/3 - 0s - 47ms/step - loss: 0.0029 - val_loss: 6.4693e-04
# Epoch 58/500
# 3/3 - 0s - 59ms/step - loss: 0.0028 - val_loss: 5.8287e-04
# Epoch 59/500
# 3/3 - 0s - 38ms/step - loss: 0.0022 - val_loss: 5.3089e-04
# Epoch 60/500
# 3/3 - 0s - 49ms/step - loss: 0.0029 - val_loss: 4.9429e-04
# Epoch 61/500
# 3/3 - 0s - 56ms/step - loss: 0.0017 - val_loss: 4.7527e-04
# Epoch 62/500
# 3/3 - 0s - 104ms/step - loss: 0.0019 - val_loss: 4.4884e-04
# Epoch 63/500
# 3/3 - 0s - 99ms/step - loss: 0.0018 - val_loss: 4.0632e-04
# Epoch 64/500
# 3/3 - 0s - 61ms/step - loss: 0.0018 - val_loss: 3.5247e-04
# Epoch 65/500
# 3/3 - 0s - 61ms/step - loss: 0.0016 - val_loss: 2.9599e-04
# Epoch 66/500
# 3/3 - 0s - 62ms/step - loss: 0.0014 - val_loss: 2.5000e-04
# Epoch 67/500
# 3/3 - 0s - 103ms/step - loss: 0.0011 - val_loss: 2.2222e-04
# Epoch 68/500
# 3/3 - 0s - 53ms/step - loss: 9.0237e-04 - val_loss: 1.9785e-04
# Epoch 69/500
# 3/3 - 0s - 99ms/step - loss: 9.0956e-04 - val_loss: 1.7307e-04
# Epoch 70/500
# 3/3 - 0s - 66ms/step - loss: 9.7289e-04 - val_loss: 1.5226e-04
# Epoch 71/500
# 3/3 - 0s - 70ms/step - loss: 6.9764e-04 - val_loss: 1.3511e-04
# Epoch 72/500
# 3/3 - 0s - 92ms/step - loss: 7.5486e-04 - val_loss: 1.2405e-04
# Epoch 73/500
# 3/3 - 0s - 106ms/step - loss: 8.5082e-04 - val_loss: 1.1167e-04
# Epoch 74/500
# 3/3 - 0s - 66ms/step - loss: 6.9599e-04 - val_loss: 9.7863e-05
# Epoch 75/500
# 3/3 - 0s - 101ms/step - loss: 7.1371e-04 - val_loss: 8.7170e-05
# Epoch 76/500
# 3/3 - 0s - 99ms/step - loss: 6.6182e-04 - val_loss: 7.9744e-05
# Epoch 77/500
# 3/3 - 0s - 91ms/step - loss: 6.2828e-04 - val_loss: 6.4916e-05
# Epoch 78/500
# 3/3 - 0s - 115ms/step - loss: 5.0790e-04 - val_loss: 5.4573e-05
# Epoch 79/500
# 3/3 - 0s - 64ms/step - loss: 6.4590e-04 - val_loss: 5.9119e-05
# Epoch 80/500
# 3/3 - 0s - 46ms/step - loss: 6.8531e-04 - val_loss: 4.6472e-05
# Epoch 81/500
# 3/3 - 0s - 37ms/step - loss: 5.3160e-04 - val_loss: 3.4986e-05
# Epoch 82/500
# 3/3 - 0s - 37ms/step - loss: 3.2170e-04 - val_loss: 3.2538e-05
# Epoch 83/500
# 3/3 - 0s - 38ms/step - loss: 3.9917e-04 - val_loss: 3.9940e-05
# Epoch 84/500
# 3/3 - 0s - 37ms/step - loss: 8.4292e-04 - val_loss: 3.1555e-05
# Epoch 85/500
# 3/3 - 0s - 41ms/step - loss: 6.2226e-04 - val_loss: 2.2774e-05
# Epoch 86/500
# 3/3 - 0s - 36ms/step - loss: 3.3799e-04 - val_loss: 3.0983e-05
# Epoch 87/500
# 3/3 - 0s - 37ms/step - loss: 5.2411e-04 - val_loss: 4.7066e-05
# Epoch 88/500
# 3/3 - 0s - 50ms/step - loss: 6.9291e-04 - val_loss: 4.6895e-05
# Epoch 89/500
# 3/3 - 0s - 38ms/step - loss: 3.8985e-04 - val_loss: 5.2173e-05
# Epoch 90/500
# 3/3 - 0s - 40ms/step - loss: 5.4542e-04 - val_loss: 5.0062e-05
# Epoch 91/500
# 3/3 - 0s - 45ms/step - loss: 3.5385e-04 - val_loss: 7.2151e-05
# Epoch 92/500
# 3/3 - 0s - 59ms/step - loss: 4.3352e-04 - val_loss: 6.5571e-05
# Epoch 93/500
# 3/3 - 0s - 44ms/step - loss: 5.4281e-04 - val_loss: 4.3565e-05
# Epoch 94/500
# 3/3 - 0s - 41ms/step - loss: 5.4357e-04 - val_loss: 3.5463e-05
# Epoch 95/500
# 3/3 - 0s - 49ms/step - loss: 5.5770e-04 - val_loss: 3.3816e-05
# Epoch 96/500
# 3/3 - 0s - 36ms/step - loss: 5.9870e-04 - val_loss: 3.3509e-05
# Epoch 97/500
# 3/3 - 0s - 39ms/step - loss: 3.8545e-04 - val_loss: 2.6897e-05
# Epoch 98/500
# 3/3 - 0s - 61ms/step - loss: 7.5264e-04 - val_loss: 2.4981e-05
# Epoch 99/500
# 3/3 - 0s - 40ms/step - loss: 4.3699e-04 - val_loss: 2.5762e-05
# Epoch 100/500
# 3/3 - 0s - 60ms/step - loss: 5.8246e-04 - val_loss: 2.3299e-05
# Epoch 101/500
# 3/3 - 0s - 87ms/step - loss: 4.1181e-04 - val_loss: 3.2877e-05
# Epoch 102/500
# 3/3 - 0s - 37ms/step - loss: 4.5089e-04 - val_loss: 4.2083e-05
# Epoch 103/500
# 3/3 - 0s - 49ms/step - loss: 6.7086e-04 - val_loss: 3.6641e-05
# Epoch 104/500
# 3/3 - 0s - 39ms/step - loss: 6.2123e-04 - val_loss: 4.6765e-05
# Epoch 105/500
# 3/3 - 0s - 45ms/step - loss: 4.8433e-04 - val_loss: 3.6745e-05
# Epoch 106/500
# 3/3 - 0s - 38ms/step - loss: 3.6508e-04 - val_loss: 2.4741e-05
# Epoch 107/500
# 3/3 - 0s - 41ms/step - loss: 5.0020e-04 - val_loss: 2.5542e-05
# Epoch 108/500
# 3/3 - 0s - 41ms/step - loss: 3.9392e-04 - val_loss: 2.4720e-05
# Epoch 109/500
# 3/3 - 0s - 46ms/step - loss: 5.0267e-04 - val_loss: 2.5899e-05
# Epoch 110/500
# 3/3 - 0s - 46ms/step - loss: 4.8972e-04 - val_loss: 2.2592e-05
# Epoch 111/500
# 3/3 - 0s - 50ms/step - loss: 4.9561e-04 - val_loss: 2.3972e-05
# Epoch 112/500
# 3/3 - 0s - 36ms/step - loss: 5.8151e-04 - val_loss: 2.7754e-05
# Epoch 113/500
# 3/3 - 0s - 48ms/step - loss: 7.7337e-04 - val_loss: 2.5225e-05
# Epoch 114/500
# 3/3 - 0s - 50ms/step - loss: 4.4967e-04 - val_loss: 2.2751e-05
# Epoch 115/500
# 3/3 - 0s - 43ms/step - loss: 4.2238e-04 - val_loss: 1.9488e-05
# Epoch 116/500
# 3/3 - 0s - 47ms/step - loss: 6.5026e-04 - val_loss: 1.7719e-05
# Epoch 117/500
# 3/3 - 0s - 45ms/step - loss: 5.5318e-04 - val_loss: 1.8146e-05
# Epoch 118/500
# 3/3 - 0s - 49ms/step - loss: 3.5755e-04 - val_loss: 2.0442e-05
# Epoch 119/500
# 3/3 - 0s - 35ms/step - loss: 3.5570e-04 - val_loss: 4.1293e-05
# Epoch 120/500
# 3/3 - 0s - 50ms/step - loss: 4.0610e-04 - val_loss: 4.6222e-05
# Epoch 121/500
# 3/3 - 0s - 37ms/step - loss: 4.1189e-04 - val_loss: 2.3705e-05
# Epoch 122/500
# 3/3 - 0s - 48ms/step - loss: 7.7964e-04 - val_loss: 1.7065e-05
# Epoch 123/500
# 3/3 - 0s - 36ms/step - loss: 3.3288e-04 - val_loss: 1.8302e-05
# Epoch 124/500
# 3/3 - 0s - 46ms/step - loss: 6.1290e-04 - val_loss: 1.8940e-05
# Epoch 125/500
# 3/3 - 0s - 48ms/step - loss: 4.5382e-04 - val_loss: 7.3663e-05
# Epoch 126/500
# 3/3 - 0s - 39ms/step - loss: 4.6435e-04 - val_loss: 9.4202e-05
# Epoch 127/500
# 3/3 - 0s - 36ms/step - loss: 5.3498e-04 - val_loss: 4.9506e-05
# Epoch 128/500
# 3/3 - 0s - 38ms/step - loss: 8.5512e-04 - val_loss: 2.3978e-05
# Epoch 129/500
# 3/3 - 0s - 38ms/step - loss: 3.9180e-04 - val_loss: 2.6960e-05
# Epoch 130/500
# 3/3 - 0s - 49ms/step - loss: 5.7755e-04 - val_loss: 4.3006e-05
# Epoch 131/500
# 3/3 - 0s - 43ms/step - loss: 7.8373e-04 - val_loss: 4.2854e-05
# Epoch 132/500
# 3/3 - 0s - 46ms/step - loss: 4.5119e-04 - val_loss: 3.4098e-05
# Epoch 133/500
# 3/3 - 0s - 50ms/step - loss: 4.5102e-04 - val_loss: 2.4237e-05
# Epoch 134/500
# 3/3 - 0s - 42ms/step - loss: 3.9838e-04 - val_loss: 2.5728e-05
# Epoch 135/500
# 3/3 - 0s - 36ms/step - loss: 7.3660e-04 - val_loss: 2.3312e-05
# Epoch 136/500
# 3/3 - 0s - 46ms/step - loss: 4.6896e-04 - val_loss: 5.0527e-05
# Epoch 137/500
# 3/3 - 0s - 50ms/step - loss: 4.5405e-04 - val_loss: 7.6186e-05
# Epoch 138/500
# 3/3 - 0s - 49ms/step - loss: 5.4394e-04 - val_loss: 4.5436e-05
# Epoch 139/500
# 3/3 - 0s - 36ms/step - loss: 5.7662e-04 - val_loss: 2.6084e-05
# Epoch 140/500
# 3/3 - 0s - 37ms/step - loss: 6.2735e-04 - val_loss: 3.4070e-05
# Epoch 141/500
# 3/3 - 0s - 45ms/step - loss: 3.6362e-04 - val_loss: 3.7331e-05
# Epoch 142/500
# 3/3 - 0s - 44ms/step - loss: 4.9210e-04 - val_loss: 2.4683e-05
# Epoch 143/500
# 3/3 - 0s - 48ms/step - loss: 3.5564e-04 - val_loss: 2.5981e-05
# Epoch 144/500
# 3/3 - 0s - 46ms/step - loss: 4.3827e-04 - val_loss: 2.3056e-05
# Epoch 145/500
# 3/3 - 0s - 40ms/step - loss: 2.8826e-04 - val_loss: 2.3935e-05
# Epoch 146/500
# 3/3 - 0s - 45ms/step - loss: 3.5744e-04 - val_loss: 3.6936e-05
# Epoch 147/500
# 3/3 - 0s - 46ms/step - loss: 4.6961e-04 - val_loss: 6.8078e-05
# Epoch 148/500
# 3/3 - 0s - 61ms/step - loss: 4.5981e-04 - val_loss: 4.5019e-05
# Epoch 149/500
# 3/3 - 0s - 39ms/step - loss: 5.7243e-04 - val_loss: 2.7121e-05
# Epoch 150/500
# 3/3 - 0s - 47ms/step - loss: 3.1721e-04 - val_loss: 1.8632e-05
# Epoch 151/500
# 3/3 - 0s - 41ms/step - loss: 3.7491e-04 - val_loss: 2.4571e-05
# Epoch 152/500
# 3/3 - 0s - 65ms/step - loss: 4.4386e-04 - val_loss: 4.0229e-05
# Epoch 153/500
# 3/3 - 0s - 98ms/step - loss: 3.8257e-04 - val_loss: 2.6687e-05
# Epoch 154/500
# 3/3 - 0s - 54ms/step - loss: 2.9342e-04 - val_loss: 2.0317e-05
# Epoch 155/500
# 3/3 - 0s - 63ms/step - loss: 5.2227e-04 - val_loss: 2.1296e-05
# Epoch 156/500
# 3/3 - 0s - 51ms/step - loss: 4.7344e-04 - val_loss: 1.8126e-05
# Epoch 157/500
# 3/3 - 0s - 59ms/step - loss: 4.3479e-04 - val_loss: 1.9299e-05
# Epoch 158/500
# 3/3 - 0s - 97ms/step - loss: 2.7665e-04 - val_loss: 1.7434e-05
# Epoch 159/500
# 3/3 - 0s - 94ms/step - loss: 3.5545e-04 - val_loss: 1.5578e-05
# Epoch 160/500
# 3/3 - 0s - 103ms/step - loss: 4.0929e-04 - val_loss: 1.7085e-05
# Epoch 161/500
# 3/3 - 0s - 68ms/step - loss: 3.9447e-04 - val_loss: 1.5303e-05
# Epoch 162/500
# 3/3 - 0s - 70ms/step - loss: 3.3747e-04 - val_loss: 1.5182e-05
# Epoch 163/500
# 3/3 - 0s - 100ms/step - loss: 2.7797e-04 - val_loss: 1.5031e-05
# Epoch 164/500
# 3/3 - 0s - 97ms/step - loss: 3.5504e-04 - val_loss: 1.7428e-05
# Epoch 165/500
# 3/3 - 0s - 104ms/step - loss: 4.2654e-04 - val_loss: 1.3433e-05
# Epoch 166/500
# 3/3 - 0s - 77ms/step - loss: 5.0727e-04 - val_loss: 1.9774e-05
# Epoch 167/500
# 3/3 - 0s - 95ms/step - loss: 4.4373e-04 - val_loss: 3.7200e-05
# Epoch 168/500
# 3/3 - 0s - 99ms/step - loss: 5.5188e-04 - val_loss: 3.3066e-05
# Epoch 169/500
# 3/3 - 0s - 94ms/step - loss: 4.9649e-04 - val_loss: 4.2687e-05
# Epoch 170/500
# 3/3 - 0s - 80ms/step - loss: 3.7778e-04 - val_loss: 4.3210e-05
# Epoch 171/500
# 3/3 - 0s - 35ms/step - loss: 5.1145e-04 - val_loss: 2.3448e-05
# Epoch 172/500
# 3/3 - 0s - 37ms/step - loss: 3.6852e-04 - val_loss: 1.6621e-05
# Epoch 173/500
# 3/3 - 0s - 35ms/step - loss: 3.9491e-04 - val_loss: 2.1639e-05
# Epoch 174/500
# 3/3 - 0s - 45ms/step - loss: 5.0808e-04 - val_loss: 1.6487e-05
# Epoch 175/500
# 3/3 - 0s - 52ms/step - loss: 3.9166e-04 - val_loss: 3.4320e-05
# Epoch 176/500
# 3/3 - 0s - 43ms/step - loss: 3.4019e-04 - val_loss: 5.4081e-05
# Epoch 177/500
# 3/3 - 0s - 45ms/step - loss: 5.4568e-04 - val_loss: 3.0183e-05
# Epoch 178/500
# 3/3 - 0s - 36ms/step - loss: 3.7876e-04 - val_loss: 1.6388e-05
# Epoch 179/500
# 3/3 - 0s - 44ms/step - loss: 4.0847e-04 - val_loss: 2.7020e-05
# Epoch 180/500
# 3/3 - 0s - 36ms/step - loss: 2.8118e-04 - val_loss: 1.1950e-05
# Epoch 181/500
# 3/3 - 0s - 47ms/step - loss: 6.4794e-04 - val_loss: 1.0375e-05
# Epoch 182/500
# 3/3 - 0s - 36ms/step - loss: 3.7071e-04 - val_loss: 1.7684e-05
# Epoch 183/500
# 3/3 - 0s - 51ms/step - loss: 4.1619e-04 - val_loss: 4.3828e-05
# Epoch 184/500
# 3/3 - 0s - 41ms/step - loss: 2.6450e-04 - val_loss: 4.0676e-05
# Epoch 185/500
# 3/3 - 0s - 47ms/step - loss: 3.0868e-04 - val_loss: 1.3412e-05
# Epoch 186/500
# 3/3 - 0s - 36ms/step - loss: 4.2281e-04 - val_loss: 1.6383e-05
# Epoch 187/500
# 3/3 - 0s - 46ms/step - loss: 2.8916e-04 - val_loss: 2.5384e-05
# Epoch 188/500
# 3/3 - 0s - 45ms/step - loss: 3.8898e-04 - val_loss: 1.5406e-05
# Epoch 189/500
# 3/3 - 0s - 46ms/step - loss: 4.3688e-04 - val_loss: 1.9064e-05
# Epoch 190/500
# 3/3 - 0s - 57ms/step - loss: 3.6101e-04 - val_loss: 8.3575e-05
# Epoch 191/500
# 3/3 - 0s - 37ms/step - loss: 5.1944e-04 - val_loss: 1.0858e-04
# Epoch 192/500
# 3/3 - 0s - 37ms/step - loss: 3.9294e-04 - val_loss: 3.0900e-05
# Epoch 193/500
# 3/3 - 0s - 46ms/step - loss: 4.0816e-04 - val_loss: 1.2337e-05
# Epoch 194/500
# 3/3 - 0s - 36ms/step - loss: 3.6812e-04 - val_loss: 1.4374e-05
# Epoch 195/500
# 3/3 - 0s - 46ms/step - loss: 2.5567e-04 - val_loss: 1.2893e-05
# Epoch 196/500
# 3/3 - 0s - 46ms/step - loss: 4.3965e-04 - val_loss: 1.3231e-05
# Epoch 197/500
# 3/3 - 0s - 36ms/step - loss: 4.2131e-04 - val_loss: 1.3059e-05
# Epoch 198/500
# 3/3 - 0s - 53ms/step - loss: 3.8969e-04 - val_loss: 2.3063e-05
# Epoch 199/500
# 3/3 - 0s - 97ms/step - loss: 3.0262e-04 - val_loss: 3.0068e-05
# Epoch 200/500
# 3/3 - 0s - 35ms/step - loss: 3.8816e-04 - val_loss: 3.4164e-05
# Epoch 201/500
# 3/3 - 0s - 48ms/step - loss: 3.5759e-04 - val_loss: 3.4392e-05
# Epoch 202/500
# 3/3 - 0s - 46ms/step - loss: 3.0775e-04 - val_loss: 2.7967e-05
# Epoch 203/500
# 3/3 - 0s - 46ms/step - loss: 4.6412e-04 - val_loss: 1.5491e-05
# Epoch 204/500
# 3/3 - 0s - 39ms/step - loss: 4.4632e-04 - val_loss: 2.2741e-05
# Epoch 205/500
# 3/3 - 0s - 44ms/step - loss: 3.6464e-04 - val_loss: 2.0462e-05
# Epoch 206/500
# 3/3 - 0s - 47ms/step - loss: 4.7383e-04 - val_loss: 1.5297e-05
# Epoch 207/500
# 3/3 - 0s - 45ms/step - loss: 4.8998e-04 - val_loss: 1.5087e-05
# Epoch 208/500
# 3/3 - 0s - 37ms/step - loss: 4.5402e-04 - val_loss: 3.3650e-05
# Epoch 209/500
# 3/3 - 0s - 46ms/step - loss: 8.0935e-04 - val_loss: 5.6912e-05
# Epoch 210/500
# 3/3 - 0s - 36ms/step - loss: 4.3018e-04 - val_loss: 3.1336e-05
# Epoch 211/500
# 3/3 - 0s - 36ms/step - loss: 2.5142e-04 - val_loss: 1.8306e-05
# Epoch 212/500
# 3/3 - 0s - 51ms/step - loss: 5.7860e-04 - val_loss: 3.0462e-05
# Epoch 213/500
# 3/3 - 0s - 35ms/step - loss: 4.4318e-04 - val_loss: 1.5995e-05
# Epoch 214/500
# 3/3 - 0s - 35ms/step - loss: 4.7506e-04 - val_loss: 5.8042e-05
# Epoch 215/500
# 3/3 - 0s - 37ms/step - loss: 4.4085e-04 - val_loss: 8.5362e-05
# Epoch 216/500
# 3/3 - 0s - 45ms/step - loss: 4.2179e-04 - val_loss: 3.3590e-05
# Epoch 217/500
# 3/3 - 0s - 46ms/step - loss: 4.4849e-04 - val_loss: 1.7858e-05
# Epoch 218/500
# 3/3 - 0s - 47ms/step - loss: 3.2448e-04 - val_loss: 2.6689e-05
# Epoch 219/500
# 3/3 - 0s - 49ms/step - loss: 4.1232e-04 - val_loss: 1.8700e-05
# Epoch 220/500
# 3/3 - 0s - 54ms/step - loss: 4.5940e-04 - val_loss: 1.3091e-05
# Epoch 221/500
# 3/3 - 0s - 88ms/step - loss: 4.3963e-04 - val_loss: 2.3567e-05
# Epoch 222/500
# 3/3 - 0s - 35ms/step - loss: 3.0325e-04 - val_loss: 3.5855e-05
# Epoch 223/500
# 3/3 - 0s - 36ms/step - loss: 3.4180e-04 - val_loss: 4.4618e-05
# Epoch 224/500
# 3/3 - 0s - 46ms/step - loss: 6.4711e-04 - val_loss: 2.9506e-05
# Epoch 225/500
# 3/3 - 0s - 61ms/step - loss: 2.8124e-04 - val_loss: 1.5958e-05
# Epoch 226/500
# 3/3 - 0s - 38ms/step - loss: 2.9831e-04 - val_loss: 1.0457e-05
# Epoch 227/500
# 3/3 - 0s - 40ms/step - loss: 4.2580e-04 - val_loss: 1.4530e-05
# Epoch 228/500
# 3/3 - 0s - 46ms/step - loss: 3.8712e-04 - val_loss: 1.3228e-05
# Epoch 229/500
# 3/3 - 0s - 35ms/step - loss: 4.3891e-04 - val_loss: 1.6737e-05
# Epoch 230/500
# 3/3 - 0s - 49ms/step - loss: 3.5060e-04 - val_loss: 2.5256e-05
# Epoch 231/500
# 3/3 - 0s - 35ms/step - loss: 3.6311e-04 - val_loss: 3.6292e-05
# Epoch 232/500
# 3/3 - 0s - 34ms/step - loss: 4.3158e-04 - val_loss: 5.0335e-05
# Epoch 233/500
# 3/3 - 0s - 49ms/step - loss: 4.2557e-04 - val_loss: 2.6717e-05
# Epoch 234/500
# 3/3 - 0s - 37ms/step - loss: 4.0512e-04 - val_loss: 1.3435e-05
# Epoch 235/500
# 3/3 - 0s - 40ms/step - loss: 4.1247e-04 - val_loss: 1.3934e-05
# Epoch 236/500
# 3/3 - 0s - 43ms/step - loss: 3.2754e-04 - val_loss: 1.2938e-05
# Epoch 237/500
# 3/3 - 0s - 36ms/step - loss: 3.5749e-04 - val_loss: 1.3183e-05
# Epoch 238/500
# 3/3 - 0s - 47ms/step - loss: 3.3794e-04 - val_loss: 1.3103e-05
# Epoch 239/500
# 3/3 - 0s - 45ms/step - loss: 3.7412e-04 - val_loss: 2.5314e-05
# Epoch 240/500
# 3/3 - 0s - 46ms/step - loss: 4.5812e-04 - val_loss: 2.7673e-05
# Epoch 241/500
# 3/3 - 0s - 49ms/step - loss: 3.4399e-04 - val_loss: 1.1939e-05
# Epoch 242/500
# 3/3 - 0s - 70ms/step - loss: 5.0292e-04 - val_loss: 1.5457e-05
# Epoch 243/500
# 3/3 - 0s - 89ms/step - loss: 4.1859e-04 - val_loss: 1.2581e-05
# Epoch 244/500
# 3/3 - 0s - 107ms/step - loss: 2.9973e-04 - val_loss: 1.6555e-05
# Epoch 245/500
# 3/3 - 0s - 68ms/step - loss: 3.5114e-04 - val_loss: 3.7921e-05
# Epoch 246/500
# 3/3 - 0s - 96ms/step - loss: 5.3232e-04 - val_loss: 2.8333e-05
# Epoch 247/500
# 3/3 - 0s - 98ms/step - loss: 3.3295e-04 - val_loss: 1.1764e-05
# Epoch 248/500
# 3/3 - 0s - 50ms/step - loss: 5.2102e-04 - val_loss: 1.3825e-05
# Epoch 249/500
# 3/3 - 0s - 102ms/step - loss: 2.2743e-04 - val_loss: 1.1760e-05
# Epoch 250/500
# 3/3 - 0s - 61ms/step - loss: 2.2767e-04 - val_loss: 3.0360e-05
# Epoch 251/500
# 3/3 - 0s - 67ms/step - loss: 2.7354e-04 - val_loss: 4.5277e-05
# Epoch 252/500
# 3/3 - 0s - 69ms/step - loss: 3.0166e-04 - val_loss: 1.8537e-05
# Epoch 253/500
# 3/3 - 0s - 58ms/step - loss: 3.5064e-04 - val_loss: 1.0777e-05
# Epoch 254/500
# 3/3 - 0s - 76ms/step - loss: 3.2594e-04 - val_loss: 1.1023e-05
# Epoch 255/500
# 3/3 - 0s - 76ms/step - loss: 4.7684e-04 - val_loss: 1.1029e-05
# Epoch 256/500
# 3/3 - 0s - 63ms/step - loss: 1.6902e-04 - val_loss: 3.1437e-05
# Epoch 257/500
# 3/3 - 0s - 56ms/step - loss: 5.8643e-04 - val_loss: 4.3218e-05
# Epoch 258/500
# 3/3 - 0s - 81ms/step - loss: 3.9073e-04 - val_loss: 2.7184e-05
# Epoch 259/500
# 3/3 - 0s - 79ms/step - loss: 3.6153e-04 - val_loss: 1.8362e-05
# Epoch 260/500
# 3/3 - 0s - 72ms/step - loss: 3.9729e-04 - val_loss: 9.2085e-06
# Epoch 261/500
# 3/3 - 0s - 91ms/step - loss: 3.3847e-04 - val_loss: 1.0186e-05
# Epoch 262/500
# 3/3 - 0s - 77ms/step - loss: 2.9896e-04 - val_loss: 9.5408e-06
# Epoch 263/500
# 3/3 - 0s - 43ms/step - loss: 2.6237e-04 - val_loss: 9.3652e-06
# Epoch 264/500
# 3/3 - 0s - 47ms/step - loss: 3.6360e-04 - val_loss: 2.0516e-05
# Epoch 265/500
# 3/3 - 0s - 38ms/step - loss: 4.5884e-04 - val_loss: 2.0222e-05
# Epoch 266/500
# 3/3 - 0s - 46ms/step - loss: 3.6762e-04 - val_loss: 1.3725e-05
# Epoch 267/500
# 3/3 - 0s - 45ms/step - loss: 3.7858e-04 - val_loss: 8.2948e-06
# Epoch 268/500
# 3/3 - 0s - 35ms/step - loss: 5.2203e-04 - val_loss: 1.6094e-05
# Epoch 269/500
# 3/3 - 0s - 49ms/step - loss: 2.9409e-04 - val_loss: 2.5717e-05
# Epoch 270/500
# 3/3 - 0s - 46ms/step - loss: 3.5128e-04 - val_loss: 1.4448e-05
# Epoch 271/500
# 3/3 - 0s - 36ms/step - loss: 4.2399e-04 - val_loss: 1.0562e-05
# Epoch 272/500
# 3/3 - 0s - 47ms/step - loss: 4.1310e-04 - val_loss: 1.0978e-05
# Epoch 273/500
# 3/3 - 0s - 49ms/step - loss: 7.3847e-04 - val_loss: 2.5348e-05
# Epoch 274/500
# 3/3 - 0s - 49ms/step - loss: 3.2869e-04 - val_loss: 3.9127e-05
# Epoch 275/500
# 3/3 - 0s - 36ms/step - loss: 3.7842e-04 - val_loss: 1.3416e-05
# Epoch 276/500
# 3/3 - 0s - 46ms/step - loss: 2.4200e-04 - val_loss: 3.0049e-05
# Epoch 277/500
# 3/3 - 0s - 48ms/step - loss: 6.1054e-04 - val_loss: 1.8441e-05
# Epoch 278/500
# 3/3 - 0s - 44ms/step - loss: 3.6590e-04 - val_loss: 2.0904e-05
# Epoch 279/500
# 3/3 - 0s - 48ms/step - loss: 3.7136e-04 - val_loss: 2.6940e-05
# Epoch 280/500
# 3/3 - 0s - 36ms/step - loss: 4.0956e-04 - val_loss: 1.4556e-05
# Epoch 281/500
# 3/3 - 0s - 48ms/step - loss: 2.8500e-04 - val_loss: 1.1617e-05
# Epoch 282/500
# 3/3 - 0s - 46ms/step - loss: 6.5801e-04 - val_loss: 1.1459e-05
# Epoch 283/500
# 3/3 - 0s - 46ms/step - loss: 4.2775e-04 - val_loss: 1.1660e-05
# Epoch 284/500
# 3/3 - 0s - 47ms/step - loss: 3.2900e-04 - val_loss: 1.1923e-05
# Epoch 285/500
# 3/3 - 0s - 36ms/step - loss: 3.4789e-04 - val_loss: 1.8617e-05
# Epoch 286/500
# 3/3 - 0s - 47ms/step - loss: 6.9399e-04 - val_loss: 4.9955e-05
# Epoch 287/500
# 3/3 - 0s - 36ms/step - loss: 3.8884e-04 - val_loss: 8.7616e-05
# Epoch 288/500
# 3/3 - 0s - 50ms/step - loss: 3.9114e-04 - val_loss: 3.1230e-05
# Epoch 289/500
# 3/3 - 0s - 36ms/step - loss: 5.8198e-04 - val_loss: 1.7864e-05
# Epoch 290/500
# 3/3 - 0s - 46ms/step - loss: 5.3489e-04 - val_loss: 1.9082e-05
# Epoch 291/500
# 3/3 - 0s - 50ms/step - loss: 5.5366e-04 - val_loss: 2.2278e-05
# Epoch 292/500
# 3/3 - 0s - 44ms/step - loss: 3.9577e-04 - val_loss: 4.9769e-05
# Epoch 293/500
# 3/3 - 0s - 46ms/step - loss: 3.9548e-04 - val_loss: 7.0590e-05
# Epoch 294/500
# 3/3 - 0s - 38ms/step - loss: 5.8966e-04 - val_loss: 2.7551e-05
# Epoch 295/500
# 3/3 - 0s - 46ms/step - loss: 4.4756e-04 - val_loss: 3.3165e-05
# Epoch 296/500
# 3/3 - 0s - 40ms/step - loss: 3.0032e-04 - val_loss: 5.2090e-05
# Epoch 297/500
# 3/3 - 0s - 36ms/step - loss: 5.1040e-04 - val_loss: 2.7952e-05
# Epoch 298/500
# 3/3 - 0s - 36ms/step - loss: 2.8558e-04 - val_loss: 1.9088e-05
# Epoch 299/500
# 3/3 - 0s - 50ms/step - loss: 5.0988e-04 - val_loss: 3.2837e-05
# Epoch 300/500
# 3/3 - 0s - 36ms/step - loss: 5.4910e-04 - val_loss: 8.1142e-06
# Epoch 301/500
# 3/3 - 0s - 37ms/step - loss: 3.6350e-04 - val_loss: 9.8577e-06
# Epoch 302/500
# 3/3 - 0s - 47ms/step - loss: 4.7210e-04 - val_loss: 1.1070e-05
# Epoch 303/500
# 3/3 - 0s - 37ms/step - loss: 2.7586e-04 - val_loss: 2.5959e-05
# Epoch 304/500
# 3/3 - 0s - 41ms/step - loss: 4.9125e-04 - val_loss: 2.9515e-05
# Epoch 305/500
# 3/3 - 0s - 39ms/step - loss: 4.2635e-04 - val_loss: 2.8924e-05
# Epoch 306/500
# 3/3 - 0s - 37ms/step - loss: 3.3692e-04 - val_loss: 2.4164e-05
# Epoch 307/500
# 3/3 - 0s - 41ms/step - loss: 3.1892e-04 - val_loss: 1.3290e-05
# Epoch 308/500
# 3/3 - 0s - 43ms/step - loss: 3.0951e-04 - val_loss: 1.5768e-05
# Epoch 309/500
# 3/3 - 0s - 45ms/step - loss: 2.9953e-04 - val_loss: 1.2376e-05
# Epoch 310/500
# 3/3 - 0s - 38ms/step - loss: 3.5463e-04 - val_loss: 2.0667e-05
# Epoch 311/500
# 3/3 - 0s - 45ms/step - loss: 2.8974e-04 - val_loss: 4.0336e-05
# Epoch 312/500
# 3/3 - 0s - 40ms/step - loss: 4.9271e-04 - val_loss: 4.7425e-05
# Epoch 313/500
# 3/3 - 0s - 35ms/step - loss: 4.1204e-04 - val_loss: 3.1771e-05
# Epoch 314/500
# 3/3 - 0s - 36ms/step - loss: 3.0165e-04 - val_loss: 2.1717e-05
# Epoch 315/500
# 3/3 - 0s - 50ms/step - loss: 3.6111e-04 - val_loss: 1.2054e-05
# Epoch 316/500
# 3/3 - 0s - 42ms/step - loss: 5.0032e-04 - val_loss: 1.3019e-05
# Epoch 317/500
# 3/3 - 0s - 37ms/step - loss: 3.2741e-04 - val_loss: 1.2393e-05
# Epoch 318/500
# 3/3 - 0s - 47ms/step - loss: 2.7669e-04 - val_loss: 1.3443e-05
# Epoch 319/500
# 3/3 - 0s - 46ms/step - loss: 3.8564e-04 - val_loss: 3.9574e-05
# Epoch 320/500
# 3/3 - 0s - 42ms/step - loss: 3.9099e-04 - val_loss: 2.9874e-05
# Epoch 321/500
# 3/3 - 0s - 42ms/step - loss: 2.6359e-04 - val_loss: 1.1390e-05
# Epoch 322/500
# 3/3 - 0s - 40ms/step - loss: 3.0170e-04 - val_loss: 8.7870e-06
# Epoch 323/500
# 3/3 - 0s - 40ms/step - loss: 2.9056e-04 - val_loss: 8.2914e-06
# Epoch 324/500
# 3/3 - 0s - 47ms/step - loss: 2.8220e-04 - val_loss: 5.1379e-06
# Epoch 325/500
# 3/3 - 0s - 45ms/step - loss: 2.8671e-04 - val_loss: 1.0782e-05
# Epoch 326/500
# 3/3 - 0s - 35ms/step - loss: 3.6887e-04 - val_loss: 1.0956e-05
# Epoch 327/500
# 3/3 - 0s - 47ms/step - loss: 3.2348e-04 - val_loss: 5.5355e-06
# Epoch 328/500
# 3/3 - 0s - 46ms/step - loss: 3.9276e-04 - val_loss: 9.5973e-06
# Epoch 329/500
# 3/3 - 0s - 47ms/step - loss: 2.6250e-04 - val_loss: 1.6745e-05
# Epoch 330/500
# 3/3 - 0s - 48ms/step - loss: 2.9816e-04 - val_loss: 1.0366e-05
# Epoch 331/500
# 3/3 - 0s - 45ms/step - loss: 3.7725e-04 - val_loss: 1.1855e-05
# Epoch 332/500
# 3/3 - 0s - 36ms/step - loss: 8.4818e-04 - val_loss: 2.0104e-05
# Epoch 333/500
# 3/3 - 0s - 46ms/step - loss: 3.5855e-04 - val_loss: 1.5229e-05
# Epoch 334/500
# 3/3 - 0s - 38ms/step - loss: 2.4784e-04 - val_loss: 4.4857e-05
# Epoch 335/500
# 3/3 - 0s - 44ms/step - loss: 3.2101e-04 - val_loss: 3.3058e-05
# Epoch 336/500
# 3/3 - 0s - 39ms/step - loss: 2.8714e-04 - val_loss: 7.6090e-06
# Epoch 337/500
# 3/3 - 0s - 61ms/step - loss: 2.3069e-04 - val_loss: 2.5054e-05
# Epoch 338/500
# 3/3 - 0s - 89ms/step - loss: 6.0841e-04 - val_loss: 6.6861e-06
# Epoch 339/500
# 3/3 - 0s - 55ms/step - loss: 3.1571e-04 - val_loss: 5.3532e-05
# Epoch 340/500
# 3/3 - 0s - 117ms/step - loss: 3.7565e-04 - val_loss: 4.3479e-05
# Epoch 341/500
# 3/3 - 0s - 64ms/step - loss: 3.3033e-04 - val_loss: 7.4784e-06
# Epoch 342/500
# 3/3 - 0s - 97ms/step - loss: 4.0422e-04 - val_loss: 7.3809e-06
# Epoch 343/500
# 3/3 - 0s - 64ms/step - loss: 2.8133e-04 - val_loss: 7.0999e-06
# Epoch 344/500
# 3/3 - 0s - 63ms/step - loss: 2.6209e-04 - val_loss: 2.2479e-05
# Epoch 345/500
# 3/3 - 0s - 95ms/step - loss: 2.9179e-04 - val_loss: 2.7766e-05
# Epoch 346/500
# 3/3 - 0s - 109ms/step - loss: 4.6269e-04 - val_loss: 7.7558e-06
# Epoch 347/500
# 3/3 - 0s - 70ms/step - loss: 2.5942e-04 - val_loss: 3.7003e-05
# Epoch 348/500
# 3/3 - 0s - 103ms/step - loss: 2.7059e-04 - val_loss: 2.7214e-05
# Epoch 349/500
# 3/3 - 0s - 96ms/step - loss: 3.4591e-04 - val_loss: 5.6416e-06
# Epoch 350/500
# 3/3 - 0s - 64ms/step - loss: 3.3522e-04 - val_loss: 1.6914e-05
# Epoch 351/500
# 3/3 - 0s - 70ms/step - loss: 2.6845e-04 - val_loss: 4.4632e-05
# Epoch 352/500
# 3/3 - 0s - 100ms/step - loss: 3.6827e-04 - val_loss: 2.0050e-05
# Epoch 353/500
# 3/3 - 0s - 101ms/step - loss: 2.6642e-04 - val_loss: 4.9354e-06
# Epoch 354/500
# 3/3 - 0s - 90ms/step - loss: 3.2542e-04 - val_loss: 1.0518e-05
# Epoch 355/500
# 3/3 - 0s - 37ms/step - loss: 2.6595e-04 - val_loss: 5.8446e-06
# Epoch 356/500
# 3/3 - 0s - 47ms/step - loss: 2.5758e-04 - val_loss: 1.7835e-05
# Epoch 357/500
# 3/3 - 0s - 44ms/step - loss: 2.8015e-04 - val_loss: 1.7436e-05
# Epoch 358/500
# 3/3 - 0s - 49ms/step - loss: 3.7774e-04 - val_loss: 1.1542e-05
# Epoch 359/500
# 3/3 - 0s - 43ms/step - loss: 3.2346e-04 - val_loss: 2.1201e-05
# Epoch 360/500
# 3/3 - 0s - 47ms/step - loss: 3.0532e-04 - val_loss: 8.6146e-06
# Epoch 361/500
# 3/3 - 0s - 37ms/step - loss: 2.3890e-04 - val_loss: 2.4882e-05
# Epoch 362/500
# 3/3 - 0s - 45ms/step - loss: 2.4713e-04 - val_loss: 1.2584e-05
# Epoch 363/500
# 3/3 - 0s - 36ms/step - loss: 3.6393e-04 - val_loss: 7.6025e-06
# Epoch 364/500
# 3/3 - 0s - 47ms/step - loss: 4.5220e-04 - val_loss: 1.0513e-05
# Epoch 365/500
# 3/3 - 0s - 55ms/step - loss: 3.9964e-04 - val_loss: 1.2422e-05
# Epoch 366/500
# 3/3 - 0s - 40ms/step - loss: 4.6452e-04 - val_loss: 1.0197e-05
# Epoch 367/500
# 3/3 - 0s - 46ms/step - loss: 4.4601e-04 - val_loss: 8.7701e-06
# Epoch 368/500
# 3/3 - 0s - 37ms/step - loss: 2.9076e-04 - val_loss: 1.3069e-05
# Epoch 369/500
# 3/3 - 0s - 37ms/step - loss: 2.7438e-04 - val_loss: 8.0901e-06
# Epoch 370/500
# 3/3 - 0s - 46ms/step - loss: 2.4460e-04 - val_loss: 2.4760e-05
# Epoch 371/500
# 3/3 - 0s - 37ms/step - loss: 2.2093e-04 - val_loss: 3.3172e-05
# Epoch 372/500
# 3/3 - 0s - 35ms/step - loss: 3.2465e-04 - val_loss: 7.3301e-06
# Epoch 373/500
# 3/3 - 0s - 57ms/step - loss: 2.6473e-04 - val_loss: 1.1316e-05
# Epoch 374/500
# 3/3 - 0s - 38ms/step - loss: 3.4059e-04 - val_loss: 5.3776e-06
# Epoch 375/500
# 3/3 - 0s - 46ms/step - loss: 2.7742e-04 - val_loss: 1.1328e-05
# Epoch 376/500
# 3/3 - 0s - 52ms/step - loss: 2.9153e-04 - val_loss: 3.1530e-05
# Epoch 377/500
# 3/3 - 0s - 38ms/step - loss: 2.7024e-04 - val_loss: 1.3173e-05
# Epoch 378/500
# 3/3 - 0s - 37ms/step - loss: 2.8586e-04 - val_loss: 4.0378e-06
# Epoch 379/500
# 3/3 - 0s - 45ms/step - loss: 3.1820e-04 - val_loss: 4.1374e-06
# Epoch 380/500
# 3/3 - 0s - 36ms/step - loss: 1.8142e-04 - val_loss: 4.0839e-06
# Epoch 381/500
# 3/3 - 0s - 48ms/step - loss: 2.5361e-04 - val_loss: 9.3090e-06
# Epoch 382/500
# 3/3 - 0s - 36ms/step - loss: 1.7603e-04 - val_loss: 3.2240e-05
# Epoch 383/500
# 3/3 - 0s - 36ms/step - loss: 2.0861e-04 - val_loss: 3.5831e-05
# Epoch 384/500
# 3/3 - 0s - 37ms/step - loss: 3.3303e-04 - val_loss: 8.8910e-06
# Epoch 385/500
# 3/3 - 0s - 45ms/step - loss: 2.7658e-04 - val_loss: 5.8309e-06
# Epoch 386/500
# 3/3 - 0s - 47ms/step - loss: 3.0561e-04 - val_loss: 5.9664e-06
# Epoch 387/500
# 3/3 - 0s - 37ms/step - loss: 3.4335e-04 - val_loss: 2.8184e-05
# Epoch 388/500
# 3/3 - 0s - 52ms/step - loss: 2.5772e-04 - val_loss: 4.5233e-05
# Epoch 389/500
# 3/3 - 0s - 57ms/step - loss: 3.9586e-04 - val_loss: 1.4055e-05
# Epoch 390/500
# 3/3 - 0s - 37ms/step - loss: 2.7411e-04 - val_loss: 1.0192e-05
# Epoch 391/500
# 3/3 - 0s - 47ms/step - loss: 2.1633e-04 - val_loss: 1.2601e-05
# Epoch 392/500
# 3/3 - 0s - 45ms/step - loss: 3.4344e-04 - val_loss: 1.9458e-05
# Epoch 393/500
# 3/3 - 0s - 36ms/step - loss: 4.0279e-04 - val_loss: 2.3399e-05
# Epoch 394/500
# 3/3 - 0s - 47ms/step - loss: 1.5608e-04 - val_loss: 1.2911e-05
# Epoch 395/500
# 3/3 - 0s - 37ms/step - loss: 2.3951e-04 - val_loss: 9.8543e-06
# Epoch 396/500
# 3/3 - 0s - 54ms/step - loss: 3.3184e-04 - val_loss: 9.1233e-06
# Epoch 397/500
# 3/3 - 0s - 37ms/step - loss: 3.7603e-04 - val_loss: 9.0632e-06
# Epoch 398/500
# 3/3 - 0s - 46ms/step - loss: 2.6827e-04 - val_loss: 2.5887e-05
# Epoch 399/500
# 3/3 - 0s - 47ms/step - loss: 2.1736e-04 - val_loss: 2.9313e-05
# Epoch 400/500
# 3/3 - 0s - 45ms/step - loss: 3.0459e-04 - val_loss: 1.5454e-05
# Epoch 401/500
# 3/3 - 0s - 51ms/step - loss: 2.4829e-04 - val_loss: 1.6387e-05
# Epoch 402/500
# 3/3 - 0s - 37ms/step - loss: 2.3683e-04 - val_loss: 1.1438e-05
# Epoch 403/500
# 3/3 - 0s - 60ms/step - loss: 3.3424e-04 - val_loss: 1.2656e-05
# Epoch 404/500
# 3/3 - 0s - 36ms/step - loss: 2.5046e-04 - val_loss: 1.4358e-05
# Epoch 405/500
# 3/3 - 0s - 36ms/step - loss: 4.3356e-04 - val_loss: 6.5979e-06
# Epoch 406/500
# 3/3 - 0s - 50ms/step - loss: 3.9693e-04 - val_loss: 3.3762e-05
# Epoch 407/500
# 3/3 - 0s - 88ms/step - loss: 3.4713e-04 - val_loss: 7.2931e-05
# Epoch 408/500
# 3/3 - 0s - 45ms/step - loss: 3.9129e-04 - val_loss: 1.5872e-05
# Epoch 409/500
# 3/3 - 0s - 44ms/step - loss: 3.3358e-04 - val_loss: 9.8174e-06
# Epoch 410/500
# 3/3 - 0s - 42ms/step - loss: 2.7935e-04 - val_loss: 9.4441e-06
# Epoch 411/500
# 3/3 - 0s - 36ms/step - loss: 3.4133e-04 - val_loss: 1.3553e-05
# Epoch 412/500
# 3/3 - 0s - 50ms/step - loss: 1.4624e-04 - val_loss: 2.4321e-05
# Epoch 413/500
# 3/3 - 0s - 43ms/step - loss: 3.8626e-04 - val_loss: 9.4758e-06
# Epoch 414/500
# 3/3 - 0s - 36ms/step - loss: 3.0339e-04 - val_loss: 1.1190e-05
# Epoch 415/500
# 3/3 - 0s - 48ms/step - loss: 2.9651e-04 - val_loss: 1.1583e-05
# Epoch 416/500
# 3/3 - 0s - 47ms/step - loss: 2.5797e-04 - val_loss: 1.2732e-05
# Epoch 417/500
# 3/3 - 0s - 45ms/step - loss: 4.3110e-04 - val_loss: 4.8677e-06
# Epoch 418/500
# 3/3 - 0s - 42ms/step - loss: 2.6840e-04 - val_loss: 2.5014e-05
# Epoch 419/500
# 3/3 - 0s - 37ms/step - loss: 1.5245e-04 - val_loss: 6.6590e-05
# Epoch 420/500
# 3/3 - 0s - 60ms/step - loss: 2.2333e-04 - val_loss: 3.1128e-05
# Epoch 421/500
# 3/3 - 0s - 37ms/step - loss: 4.2385e-04 - val_loss: 6.1158e-06
# Epoch 422/500
# 3/3 - 0s - 39ms/step - loss: 6.3725e-04 - val_loss: 5.5949e-06
# Epoch 423/500
# 3/3 - 0s - 36ms/step - loss: 2.2828e-04 - val_loss: 1.6244e-05
# Epoch 424/500
# 3/3 - 0s - 49ms/step - loss: 2.0413e-04 - val_loss: 2.1513e-05
# Epoch 425/500
# 3/3 - 0s - 50ms/step - loss: 2.9460e-04 - val_loss: 1.3333e-05
# Epoch 426/500
# 3/3 - 0s - 36ms/step - loss: 2.2587e-04 - val_loss: 9.5859e-06
# Epoch 427/500
# 3/3 - 0s - 35ms/step - loss: 2.8304e-04 - val_loss: 1.0173e-05
# Epoch 428/500
# 3/3 - 0s - 74ms/step - loss: 2.1290e-04 - val_loss: 9.6257e-06
# Epoch 429/500
# 3/3 - 0s - 97ms/step - loss: 3.0801e-04 - val_loss: 9.6386e-06
# Epoch 430/500
# 3/3 - 0s - 100ms/step - loss: 3.3209e-04 - val_loss: 1.9732e-05
# Epoch 431/500
# 3/3 - 0s - 66ms/step - loss: 4.5507e-04 - val_loss: 1.9022e-05
# Epoch 432/500
# 3/3 - 0s - 96ms/step - loss: 3.4503e-04 - val_loss: 7.3508e-06
# Epoch 433/500
# 3/3 - 0s - 63ms/step - loss: 1.9496e-04 - val_loss: 1.4114e-05
# Epoch 434/500
# 3/3 - 0s - 63ms/step - loss: 1.7375e-04 - val_loss: 7.1686e-06
# Epoch 435/500
# 3/3 - 0s - 72ms/step - loss: 2.7739e-04 - val_loss: 3.6247e-05
# Epoch 436/500
# 3/3 - 0s - 91ms/step - loss: 4.0957e-04 - val_loss: 1.7099e-05
# Epoch 437/500
# 3/3 - 0s - 60ms/step - loss: 2.9078e-04 - val_loss: 8.3152e-06
# Epoch 438/500
# 3/3 - 0s - 106ms/step - loss: 2.8137e-04 - val_loss: 9.7138e-06
# Epoch 439/500
# 3/3 - 0s - 112ms/step - loss: 3.3357e-04 - val_loss: 1.6877e-05
# Epoch 440/500
# 3/3 - 0s - 89ms/step - loss: 2.1457e-04 - val_loss: 5.8218e-05
# Epoch 441/500
# 3/3 - 0s - 105ms/step - loss: 3.5947e-04 - val_loss: 2.8940e-05
# Epoch 442/500
# 3/3 - 0s - 95ms/step - loss: 2.3790e-04 - val_loss: 8.9732e-06
# Epoch 443/500
# 3/3 - 0s - 70ms/step - loss: 2.1702e-04 - val_loss: 9.6782e-06
# Epoch 444/500
# 3/3 - 0s - 89ms/step - loss: 3.7299e-04 - val_loss: 1.3926e-05
# Epoch 445/500
# 3/3 - 0s - 98ms/step - loss: 2.2987e-04 - val_loss: 3.0622e-05
# Epoch 446/500
# 3/3 - 0s - 37ms/step - loss: 4.0498e-04 - val_loss: 1.1141e-05
# Epoch 447/500
# 3/3 - 0s - 53ms/step - loss: 2.5452e-04 - val_loss: 1.7173e-05
# Epoch 448/500
# 3/3 - 0s - 43ms/step - loss: 2.9252e-04 - val_loss: 2.0067e-05
# Epoch 449/500
# 3/3 - 0s - 39ms/step - loss: 3.0621e-04 - val_loss: 6.4107e-06
# Epoch 450/500
# 3/3 - 0s - 40ms/step - loss: 4.7807e-04 - val_loss: 5.0199e-06
# Epoch 451/500
# 3/3 - 0s - 51ms/step - loss: 3.3252e-04 - val_loss: 6.7478e-06
# Epoch 452/500
# 3/3 - 0s - 40ms/step - loss: 2.5399e-04 - val_loss: 1.7250e-06
# Epoch 453/500
# 3/3 - 0s - 46ms/step - loss: 2.1162e-04 - val_loss: 1.6841e-06
# Epoch 454/500
# 3/3 - 0s - 37ms/step - loss: 2.0899e-04 - val_loss: 7.6783e-07
# Epoch 455/500
# 3/3 - 0s - 41ms/step - loss: 4.4107e-04 - val_loss: 1.0082e-05
# Epoch 456/500
# 3/3 - 0s - 38ms/step - loss: 1.9872e-04 - val_loss: 1.8763e-05
# Epoch 457/500
# 3/3 - 0s - 37ms/step - loss: 2.0843e-04 - val_loss: 6.3732e-06
# Epoch 458/500
# 3/3 - 0s - 45ms/step - loss: 2.6153e-04 - val_loss: 1.3980e-06
# Epoch 459/500
# 3/3 - 0s - 51ms/step - loss: 3.3970e-04 - val_loss: 2.5876e-06
# Epoch 460/500
# 3/3 - 0s - 38ms/step - loss: 3.3365e-04 - val_loss: 1.8193e-06
# Epoch 461/500
# 3/3 - 0s - 47ms/step - loss: 3.5290e-04 - val_loss: 4.9709e-06
# Epoch 462/500
# 3/3 - 0s - 47ms/step - loss: 3.1433e-04 - val_loss: 2.1085e-05
# Epoch 463/500
# 3/3 - 0s - 44ms/step - loss: 2.6878e-04 - val_loss: 2.0080e-05
# Epoch 464/500
# 3/3 - 0s - 36ms/step - loss: 3.4949e-04 - val_loss: 1.0576e-05
# Epoch 465/500
# 3/3 - 0s - 37ms/step - loss: 3.5714e-04 - val_loss: 1.1081e-05
# Epoch 466/500
# 3/3 - 0s - 36ms/step - loss: 3.4130e-04 - val_loss: 1.6858e-05
# Epoch 467/500
# 3/3 - 0s - 40ms/step - loss: 3.3118e-04 - val_loss: 1.1716e-05
# Epoch 468/500
# 3/3 - 0s - 44ms/step - loss: 2.6895e-04 - val_loss: 1.6143e-05
# Epoch 469/500
# 3/3 - 0s - 37ms/step - loss: 2.4219e-04 - val_loss: 1.8616e-05
# Epoch 470/500
# 3/3 - 0s - 38ms/step - loss: 3.7666e-04 - val_loss: 1.0607e-05
# Epoch 471/500
# 3/3 - 0s - 43ms/step - loss: 2.3904e-04 - val_loss: 1.3388e-05
# Epoch 472/500
# 3/3 - 0s - 42ms/step - loss: 1.7037e-04 - val_loss: 1.1071e-05
# Epoch 473/500
# 3/3 - 0s - 39ms/step - loss: 2.4855e-04 - val_loss: 1.0124e-05
# Epoch 474/500
# 3/3 - 0s - 46ms/step - loss: 3.3689e-04 - val_loss: 1.4262e-05
# Epoch 475/500
# 3/3 - 0s - 46ms/step - loss: 3.3434e-04 - val_loss: 2.0255e-06
# Epoch 476/500
# 3/3 - 0s - 45ms/step - loss: 2.4936e-04 - val_loss: 3.8772e-05
# Epoch 477/500
# 3/3 - 0s - 47ms/step - loss: 3.1055e-04 - val_loss: 5.5735e-05
# Epoch 478/500
# 3/3 - 0s - 59ms/step - loss: 2.6054e-04 - val_loss: 7.0673e-06
# Epoch 479/500
# 3/3 - 0s - 37ms/step - loss: 2.9776e-04 - val_loss: 1.2746e-05
# Epoch 480/500
# 3/3 - 0s - 36ms/step - loss: 2.6389e-04 - val_loss: 1.3918e-05
# Epoch 481/500
# 3/3 - 0s - 47ms/step - loss: 2.5677e-04 - val_loss: 4.5376e-06
# Epoch 482/500
# 3/3 - 0s - 43ms/step - loss: 2.5300e-04 - val_loss: 3.9863e-05
# Epoch 483/500
# 3/3 - 0s - 38ms/step - loss: 3.7104e-04 - val_loss: 3.4111e-05
# Epoch 484/500
# 3/3 - 0s - 59ms/step - loss: 5.2647e-04 - val_loss: 5.9460e-06
# Epoch 485/500
# 3/3 - 0s - 88ms/step - loss: 3.5246e-04 - val_loss: 2.1410e-05
# Epoch 486/500
# 3/3 - 0s - 45ms/step - loss: 3.7930e-04 - val_loss: 1.0012e-05
# Epoch 487/500
# 3/3 - 0s - 45ms/step - loss: 5.0956e-04 - val_loss: 3.6577e-05
# Epoch 488/500
# 3/3 - 0s - 47ms/step - loss: 2.9400e-04 - val_loss: 1.0541e-04
# Epoch 489/500
# 3/3 - 0s - 46ms/step - loss: 2.6918e-04 - val_loss: 4.0468e-05
# Epoch 490/500
# 3/3 - 0s - 39ms/step - loss: 2.9740e-04 - val_loss: 2.0429e-05
# Epoch 491/500
# 3/3 - 0s - 44ms/step - loss: 2.9192e-04 - val_loss: 4.3690e-05
# Epoch 492/500
# 3/3 - 0s - 51ms/step - loss: 3.1016e-04 - val_loss: 1.7629e-05
# Epoch 493/500
# 3/3 - 0s - 37ms/step - loss: 2.5082e-04 - val_loss: 1.8193e-05
# Epoch 494/500
# 3/3 - 0s - 37ms/step - loss: 2.3351e-04 - val_loss: 2.5869e-05
# Epoch 495/500
# 3/3 - 0s - 48ms/step - loss: 3.4605e-04 - val_loss: 1.0581e-05
# Epoch 496/500
# 3/3 - 0s - 45ms/step - loss: 1.9264e-04 - val_loss: 1.2519e-05
# Epoch 497/500
# 3/3 - 0s - 39ms/step - loss: 3.2841e-04 - val_loss: 1.3026e-05
# Epoch 498/500
# 3/3 - 0s - 36ms/step - loss: 3.0184e-04 - val_loss: 1.0566e-05
# Epoch 499/500
# 3/3 - 0s - 47ms/step - loss: 2.1212e-04 - val_loss: 2.8347e-06
# Epoch 500/500
# 3/3 - 0s - 52ms/step - loss: 2.4400e-04 - val_loss: 1.0991e-05

# %% [markdown]
# ##Hasil Prediksi

# %%
# Make a prediction

# Kode untuk data pelatihan (train data)
# Make a prediction for training data
xhat = best_model.predict(train_X)

# Invert scaling for forecast (training data)
inv_xhat = np.concatenate((xhat, train_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_xhat = scaler.inverse_transform(inv_xhat.reshape(-1, inv_xhat.shape[-1]))  # Flatten then inverse transform
inv_xhat = inv_xhat[:,0]

# Invert scaling for actual (training data)
train_y = train_y.reshape((len(train_y), 1))
inv_x = np.concatenate((train_y, train_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_x = scaler.inverse_transform(inv_x.reshape(-1, inv_x.shape[-1]))  # Flatten then inverse transform
inv_x = inv_x[:,0]

# Kode untuk data pelatihan (test data)
# Make a prediction for test data
yhat = best_model.predict(test_X)

# Invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat.reshape(-1, inv_yhat.shape[-1]))  # Flatten then inverse transform
inv_yhat = inv_yhat[:,0]

# Invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, :, -1].reshape(-1, 1)), axis=1)
inv_y = scaler.inverse_transform(inv_y.reshape(-1, inv_y.shape[-1]))  # Flatten then inverse transform
inv_y = inv_y[:,0]

# Calculate RMSE for training data
train_rmse = np.sqrt(mean_squared_error(inv_x, inv_xhat))
print('Train RMSE: %.3f' % train_rmse)

# Calculate MAPE for training data
train_mape = mean_absolute_percentage_error(inv_x, inv_xhat)
print('Train MAPE: %.3f' % train_mape)


# Calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)

# Calculate MAPE
mape = mean_absolute_percentage_error(inv_y, inv_yhat)
print('Test MAPE: %.3f' % mape)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Train RMSE: 1.229
# Train MAPE: 0.014
# Test RMSE: 1.176
# Test MAPE: 0.011

# %%
## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 200 hours.

# Adjust the range of aa to match the length of inv_y and inv_yhat


aa=[x for x in range(len(inv_x))] # Change this line

plt.plot(aa, inv_x, marker='.', label="actual") # Remove slicing [:200]
plt.plot(aa, inv_xhat, 'r', label="prediction") # Remove slicing [:200]
plt.title('Model Performance Data train')
plt.ylabel('Jumlah Pengunjung', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# Adjust the range of aa to match the length of inv_y and inv_yhat
aa=[x for x in range(len(inv_y))] # Change this line

plt.plot(aa, inv_y, marker='.', label="actual") # Remove slicing [:200]
plt.plot(aa, inv_yhat, 'r', label="prediction") # Remove slicing [:200]
plt.title('Model Performance Data test')
plt.ylabel('Jumlah Pengunjung', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()
